# %%
from hashlib import md5
from time import time
from typing import Dict, List, Set, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from cnn_net import HalfConvNet
from torch.utils.data import DataLoader, Subset

from alphafed import logger
from alphafed.hetero_nn import HeteroNNHostScheduler


# 本示例中使用的推理模型很简单，所以直接在脚本中定义。现实中如果模型比较复杂，
# 也可以参考 HalfConvNet 放在独立文件中然后引入。
class InferModule(nn.Module):

    def __init__(self) -> None:
        super().__init__()
        self.fc1 = nn.Linear(40, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, input):
        out = F.relu(self.fc1(input))
        out = self.fc2(out)
        return F.log_softmax(out, dim=-1)


class DemoHeteroHost(HeteroNNHostScheduler):

    def __init__(self,
                 feature_key: str,
                 batch_size: int,
                 max_rounds: int = 0,
                 calculation_timeout: int = 300,
                 log_rounds: int = 0) -> None:
        """初始化参数说明.

        以下为 `HeteroNNHostScheduler` 父类定义的初始化参数。
        feature_key:
            当前参与方的特征 key 标识，用于在特征聚合时区分特征来源，以支持区别化处理。
            train_a_batch 和 test 方法中使用的 feature_key 参数既来自于这里。
        max_rounds:
            训练多少轮。
        calculation_timeout:
            本地训练超时时间。
        log_rounds:
            每隔几轮训练执行一次测试，评估记录当前训练效果。

        以下 `DemoHeteroHost` 自定义的扩展初始化参数。
        batch_size:
            训练参数。
        """
        super().__init__(feature_key=feature_key,
                         max_rounds=max_rounds,
                         calculation_timeout=calculation_timeout,
                         log_rounds=log_rounds)
        self.batch_size = batch_size

    def load_local_ids(self) -> List[str]:
        # 聚合方取 MNIST 训练样本的前 20000 个、测试样本的前 5000 个，
        # 协作方取 MNIST 训练样本的第 10000 - 30000 个、测试样本的第 3000 - 7000 个.
        # 求交后共有训练样本 10000 个，测试样本 2000 个。
        # 为避免 ID 冲突，测试样本 ID 全部加 100000，以使其和训练样本 ID 不重合
        train_ids = [str(i) for i in range(0, 20000)]
        test_ids = [str(i) for i in range(100000, 105000)]
        return train_ids + test_ids

    def split_dataset(self, id_intersection: Set[str]) -> Tuple[Set[str], Set[str]]:
        # 示例中训练样本 ID < 100000，测试样本 ID >= 100000，排序后前 10000 个样本为训练样本 ID。
        ids = [int(_id) for _id in id_intersection]
        ids.sort()
        train_ids = ids[:10000]
        test_ids = ids[10000:]

        logger.info(f'Got {len(train_ids)} intersecting samples for training.')
        logger.info(f'Got {len(test_ids)} intersecting samples for testing.')

        return set(train_ids), set(test_ids)

    def build_feature_model(self) -> nn.Module:
        return HalfConvNet()

    def build_feature_optimizer(self, feature_model: nn.Module) -> optim.Optimizer:
        return optim.SGD(feature_model.parameters(), lr=0.01, momentum=0.9)

    def _erase_right(self, _image: torch.Tensor) -> torch.Tensor:
        return _image[:, :, :, :14]

    def iterate_train_feature(self,
                              feature_model: nn.Module,
                              train_ids: Set[str]) -> Tuple[torch.Tensor, torch.Tensor]:
        train_dataset = torchvision.datasets.MNIST(
            'data',
            train=True,
            download=True,
            transform=torchvision.transforms.Compose([
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize((0.1307,), (0.3081,))
            ])
        )
        # 每一轮训练时，根据“样本 ID + 当前轮次”的哈希值对样本排序，既可以对每个训练轮次的
        # 样本随机重排序，又可以保证不同参与方随机重排后的样本依然是对齐的。
        train_ids: List = list(train_ids)
        train_ids.sort(key=lambda x: md5(bytes(x + self.current_round)).digest())

        train_dataset = Subset(train_dataset, train_ids)
        self.train_loader = DataLoader(train_dataset,
                                       batch_size=self.batch_size,
                                       shuffle=False)

        for _data, _labels in self.train_loader:
            _data = self._erase_right(_data)
            yield feature_model(_data), _labels

    def iterate_test_feature(self,
                             feature_model: nn.Module,
                             test_ids: Set[str]) -> Tuple[torch.Tensor, torch.Tensor]:
        test_dataset = torchvision.datasets.MNIST(
            'data',
            train=False,
            download=True,
            transform=torchvision.transforms.Compose([
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize((0.1307,), (0.3081,))
            ])
        )
        test_ids = [(i - 100000) for i in test_ids]
        test_dataset = Subset(test_dataset, test_ids)
        self.test_loader = DataLoader(test_dataset,
                                      batch_size=self.batch_size,
                                      shuffle=False)

        for _data, _labels in self.test_loader:
            _data = self._erase_right(_data)
            yield feature_model(_data), _labels

    def build_infer_model(self) -> nn.Module:
        return InferModule()

    def build_infer_optimizer(self, infer_model: nn.Module) -> optim.Optimizer:
        return optim.SGD(infer_model.parameters(), lr=0.01, momentum=0.9)

    def train_a_batch(self, feature_projection: Dict[str, torch.Tensor], labels: torch.Tensor):
        fusion_tensor = torch.concat((feature_projection['demo_host'],
                                      feature_projection['demo_collaborator']), dim=1)
        self.optimizer.zero_grad()
        out = self.infer_model(fusion_tensor)
        loss = F.nll_loss(out, labels)
        loss.backward()
        self.optimizer.step()

    def run_test(self,
                 batched_feature_projections: List[torch.Tensor],
                 batched_labels: List[torch.Tensor]):
        # 测试时也需要各个参与方提供本地测试数据对应的特征张量
        start = time()
        test_loss = 0
        correct = 0
        for _feature_projection, _lables in zip(batched_feature_projections, batched_labels):
            fusion_tensor = torch.concat((_feature_projection['demo_host'],
                                          _feature_projection['demo_collaborator']), dim=1)
            out: torch.Tensor = self.infer_model(fusion_tensor)
            test_loss += F.nll_loss(out, _lables)
            pred = out.max(1, keepdim=True)[1]
            correct += pred.eq(_lables.view_as(pred)).sum().item()

        end = time()

        test_loss /= len(self.test_loader.dataset)
        accuracy = correct / len(self.test_loader.dataset)
        correct_rate = 100. * accuracy

        self.tb_writer.add_scalar('timer/run_time', end - start, self.current_round)
        self.tb_writer.add_scalar('test_results/average_loss', test_loss, self.current_round)
        self.tb_writer.add_scalar('test_results/accuracy', accuracy, self.current_round)
        self.tb_writer.add_scalar('test_results/correct_rate', correct_rate, self.current_round)

# %%
from alphafed import mock_context


# 聚合方的模拟启动脚本
scheduler = DemoHeteroHost(
    feature_key='demo_host',
    batch_size=128,  # 各个参与方需要设置相同的 batch_size，否则数据无法对齐
    max_rounds=5,  # 受本地资源限制，运行速度可能会很慢，调试时不建议设置太高
    calculation_timeout=1800,  # 受本地资源限制，运行速度可能会很慢，设置太低容易导致超时
    log_rounds=1
)

aggregator_id = '9afb99da-2e4c-4676-a434-5f312f583947'  # 设置一个假想 ID
task_id = '5a8c6b50-6267-4258-afb0-a4e7413ead58'  # 设置一个假想 ID
# 算法实际运行时会从任务管理器获取任务参与节点的 Node ID 列表，但是在模拟环境不能通过
# 访问实际接口获得这个信息，所以需要通过 nodes 参数将这个列表配置在模拟环境中。
collaborate_id = 'ec72a25c-ff83-47f2-a4bc-74321acace99'  # 设置一个假想 ID
with mock_context(id=aggregator_id, nodes=[aggregator_id, collaborate_id]):  # 在模拟调试环境中运行
    # _run 接口是最底层的 Scheduler 接口定义的，横向联邦、异构联邦框架都实现了对应接口
    scheduler._run(id=aggregator_id, task_id=task_id, is_initiator=True)
# Out:
# 2023-02-02 08:39:39,538|DEBUG|scheduler|_switch_status|125:
# self.status='init'
# 2023-02-02 08:39:39,541|INFO|scheduler|push_log|118:
# Begin to validate local context.
# 2023-02-02 08:39:39,543|INFO|scheduler|push_log|118:
# Local context is ready.
# 2023-02-02 08:39:39,544|INFO|scheduler|push_log|118:
# Node 9afb99da-2e4c-4676-a434-5f312f583947 is up.
# 2023-02-02 08:39:39,545|DEBUG|scheduler|_switch_status|125:
# self.status='gethoring'
# 2023-02-02 08:39:39,546|INFO|scheduler|push_log|118:
# Waiting for participants taking part in ...
# 2023-02-02 08:39:45,561|INFO|scheduler|push_log|118:
# Welcome a new partner ID: ec72a25c-ff83-47f2-a4bc-74321acace99.
# 2023-02-02 08:39:45,562|INFO|scheduler|push_log|118:
# There are 1 partners now.
# 2023-02-02 08:39:45,569|INFO|scheduler|push_log|118:
# All partners have gethored.
# 2023-02-02 08:39:45,569|DEBUG|scheduler|_switch_status|125:
# self.status='ready'
# 2023-02-02 08:39:45,570|DEBUG|scheduler|_switch_status|125:
# self.status='synchronizing'
# 2023-02-02 08:39:45,571|INFO|scheduler|push_log|118:
# Initiate state synchronization of round 1.
# 2023-02-02 08:39:45,583|INFO|scheduler|push_log|118:
# Waiting for synchronization responses ...
# 2023-02-02 08:39:46,609|INFO|scheduler|push_log|118:
# Successfully synchronized state with ID: ec72a25c-ff83-47f2-a4bc-74321acace99.
# 2023-02-02 08:39:46,610|INFO|scheduler|push_log|118:
# Successfully synchronized state in round 1
# 2023-02-02 08:39:46,611|DEBUG|scheduler|_switch_status|125:
# self.status='id_intersection'
# 2023-02-02 08:39:46,618|DEBUG|psi|_switch_status|66:
# self.status='init'
# 2023-02-02 08:39:46,619|DEBUG|psi|_switch_status|66:
# self.status='kicking_off'
# 2023-02-02 08:39:46,626|DEBUG|psi|_switch_status|66:
# self.status='collecting_pub_key'
# 2023-02-02 08:39:47,714|DEBUG|psi|_switch_status|66:
# self.status='sending_blind_ids'
# 2023-02-02 08:39:54,521|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:39:54,595|DEBUG|psi|_switch_status|66:
# self.status='collecting_signed_ids'
# 2023-02-02 08:40:14,362|DEBUG|psi|_switch_status|66:
# self.status='intersecting'
# 2023-02-02 08:40:14,554|DEBUG|psi|_switch_status|66:
# self.status='distributing_intersection'
# 2023-02-02 08:40:15,893|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:15,979|DEBUG|scheduler|_switch_status|125:
# self.status='in_a_round'
# 2023-02-02 08:40:15,979|INFO|scheduler|push_log|118:
# Begin the training of round 1.
# 2023-02-02 08:40:15,992|INFO|scheduler|push_log|118:
# Calculation of round 1 is started.
# 2023-02-02 08:40:15,997|INFO|5758515|split_dataset|79:
# Got 10000 intersecting samples for training.
# 2023-02-02 08:40:15,998|INFO|5758515|split_dataset|80:
# Got 2000 intersecting samples for testing.
# 2023-02-02 08:40:16,298|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:16,299|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:16,301|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:18,945|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:18,946|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:18,952|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:18,953|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:20,088|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:20,157|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:20,175|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:20,176|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:20,177|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:21,603|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:21,604|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:21,610|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:21,610|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:22,736|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:22,816|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:22,834|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:22,835|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:22,836|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:25,480|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:25,481|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:25,487|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:25,488|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:26,597|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:26,693|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:26,712|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:26,712|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:26,713|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:29,037|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:29,038|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:29,045|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:29,046|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:30,164|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:30,251|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:30,269|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:30,270|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:30,271|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:32,594|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:32,595|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:32,600|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:32,602|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:33,736|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:33,806|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:33,825|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:33,826|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:33,828|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:35,375|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:35,376|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:35,382|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:35,383|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:36,512|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:36,587|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:36,610|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:36,611|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:36,612|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:37,950|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:37,950|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:37,956|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:37,957|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:39,059|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:39,062|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:39,081|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:39,081|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:39,082|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:40,407|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:40,408|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:40,413|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:40,414|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:41,537|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:41,619|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:41,638|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:41,639|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:41,639|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:43,170|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:43,171|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:43,177|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:43,177|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:44,333|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:44,383|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:44,401|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:44,402|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:44,402|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:45,935|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:45,935|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:45,940|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:45,941|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:47,060|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:47,146|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:47,165|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:47,166|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:47,167|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:48,701|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:48,702|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:48,708|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:48,709|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:49,833|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:49,914|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:49,932|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:49,933|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:49,934|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:51,254|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:51,255|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:51,261|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:51,262|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:52,401|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:52,467|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:52,485|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:52,485|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:52,486|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:54,829|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:54,830|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:54,835|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:54,835|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:55,936|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:55,939|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:55,964|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:55,965|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:55,966|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:57,286|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:57,287|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:57,292|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:57,293|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:40:58,397|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:58,498|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:40:58,517|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:58,518|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:40:58,519|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:40:59,849|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:40:59,850|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:40:59,855|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:40:59,856|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:00,991|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:01,061|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:01,080|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:01,082|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:01,083|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:02,626|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:02,627|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:02,633|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:02,634|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:03,761|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:03,838|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:03,858|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:03,859|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:03,860|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:05,389|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:05,389|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:05,394|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:05,395|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:06,544|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:06,601|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:06,619|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:06,620|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:06,621|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:07,941|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:07,942|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:07,947|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:07,947|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:09,065|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:09,152|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:09,173|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:09,174|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:09,175|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:10,604|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:10,605|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:10,610|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:10,611|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:11,736|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:11,816|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:11,834|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:11,834|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:11,835|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:13,161|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:13,162|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:13,168|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:13,169|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:14,301|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:14,372|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:14,391|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:14,391|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:14,392|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:15,923|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:15,924|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:15,929|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:15,930|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:17,057|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:17,135|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:17,154|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:17,155|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:17,155|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:18,480|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:18,481|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:18,487|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:18,487|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:19,607|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:19,693|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:19,712|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:19,713|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:19,714|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:21,042|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:21,043|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:21,049|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:21,050|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:22,146|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:22,155|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:22,173|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:22,174|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:22,175|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:23,510|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:23,511|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:23,515|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:23,516|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:24,634|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:24,720|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:24,738|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:24,739|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:24,739|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:26,063|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:26,064|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:26,070|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:26,070|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:27,183|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:27,276|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:27,294|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:27,295|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:27,296|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:28,615|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:28,616|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:28,621|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:28,622|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:29,720|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:29,727|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:29,746|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:29,747|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:29,748|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:31,074|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:31,075|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:31,080|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:31,081|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:32,203|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:32,286|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:32,304|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:32,305|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:32,306|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:34,640|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:34,640|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:34,645|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:34,646|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:35,795|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:35,852|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:35,870|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:35,871|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:35,872|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:38,195|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:38,196|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:38,202|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:38,203|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:39,328|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:39,409|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:39,427|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:39,428|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:39,429|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:41,961|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:41,962|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:41,967|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:41,968|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:43,131|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:43,173|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:43,191|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:43,192|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:43,193|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:44,514|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:44,514|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:44,519|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:44,520|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:45,665|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:45,725|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:45,743|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:45,744|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:45,745|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:47,068|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:47,069|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:47,074|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:47,075|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:48,191|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:48,278|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:48,297|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:48,299|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:48,299|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:49,632|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:49,633|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:49,639|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:49,639|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:50,754|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:50,844|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:50,862|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:50,863|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:50,863|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:52,188|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:52,189|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:52,195|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:52,195|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:53,317|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:53,400|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:53,420|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:53,421|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:53,421|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:54,744|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:54,745|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:54,750|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:54,750|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:55,853|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:55,855|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:55,874|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:55,875|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:55,875|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:57,200|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:57,201|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:57,206|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:57,207|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:41:58,314|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:58,412|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:41:58,431|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:58,432|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:41:58,433|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:41:59,861|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:41:59,861|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:41:59,868|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:41:59,868|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:01,009|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:01,076|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:01,094|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:01,095|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:01,096|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:03,431|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:03,432|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:03,438|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:03,439|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:04,560|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:04,644|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:04,662|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:04,663|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:04,664|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:05,985|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:05,986|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:05,993|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:05,994|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:07,124|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:07,199|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:07,221|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:07,224|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:07,225|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:08,546|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:08,547|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:08,552|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:08,553|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:09,692|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:09,758|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:09,780|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:09,781|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:09,781|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:11,114|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:11,118|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:11,128|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:11,130|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:12,240|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:12,334|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:12,356|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:12,357|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:12,359|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:13,681|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:13,682|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:13,688|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:13,688|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:14,793|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:14,894|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:14,912|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:14,913|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:14,915|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:16,237|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:16,238|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:16,243|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:16,244|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:17,387|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:17,449|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:17,490|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:17,491|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:17,492|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:18,816|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:18,817|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:18,822|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:18,823|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:19,947|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:20,027|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:20,050|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:20,053|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:20,053|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:21,386|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:21,387|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:21,393|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:21,394|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:22,528|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:22,598|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:22,617|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:22,618|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:22,620|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:23,941|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:23,942|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:23,947|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:23,948|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:25,068|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:25,152|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:25,171|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:25,171|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:25,172|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:26,499|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:26,500|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:26,505|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:26,506|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:27,628|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:27,709|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:27,731|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:27,732|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:27,733|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:29,057|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:29,058|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:29,067|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:29,068|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:30,197|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:30,272|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:30,295|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:30,296|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:30,296|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:31,726|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:31,727|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:31,732|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:31,732|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:32,871|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:32,936|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:32,954|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:32,955|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:32,955|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:34,276|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:34,277|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:34,282|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:34,283|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:35,413|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:35,487|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:35,506|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:35,507|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:35,509|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:36,834|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:36,835|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:36,840|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:36,841|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:37,949|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:38,047|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:42:38,067|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:38,068|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:42:38,068|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:42:40,392|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:42:40,393|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:42:40,399|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:42:40,399|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:42:41,533|DEBUG|shared_file_data_channel|_do_send_stream|136:
# ...
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:43,160|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:43,161|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:43,166|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:43,167|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:44,300|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:44,372|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:44,389|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:44,390|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:44,391|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:45,713|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:45,714|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:45,719|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:45,720|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:46,878|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:46,925|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:46,943|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:46,944|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:46,944|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:48,269|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:48,270|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:48,275|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:48,276|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:49,379|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:49,382|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:49,399|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:49,400|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:49,400|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:50,946|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:50,947|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:50,953|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:50,954|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:52,113|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:52,159|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:52,176|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:52,178|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:52,179|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:53,524|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:53,524|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:53,531|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:53,531|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:54,662|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:54,735|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:54,752|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:54,753|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:54,754|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:56,080|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:56,080|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:56,085|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:56,086|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:57,195|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:57,291|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:57,309|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:57,311|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:57,312|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:57:58,637|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:57:58,638|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:57:58,643|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:57:58,644|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:57:59,767|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:59,848|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:57:59,866|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:59,866|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:57:59,867|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:01,192|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:01,193|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:01,198|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:01,198|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:02,323|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:02,404|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:02,422|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:02,423|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:02,424|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:03,961|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:03,962|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:03,968|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:03,968|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:05,106|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:05,174|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:05,197|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:05,198|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:05,200|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:06,631|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:06,632|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:06,638|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:06,640|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:07,763|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:07,849|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:07,878|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:07,880|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:07,883|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:10,221|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:10,222|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:10,227|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:10,228|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:11,342|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:11,433|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:11,454|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:11,455|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:11,456|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:13,793|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:13,794|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:13,800|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:13,800|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:14,945|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:15,005|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:15,024|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:15,025|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:15,026|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:17,359|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:17,360|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:17,366|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:17,372|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:18,514|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:18,576|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:18,594|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:18,595|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:18,595|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:20,933|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:20,933|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:20,939|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:20,940|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:22,063|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:22,145|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:22,162|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:22,163|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:22,164|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:24,610|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:24,611|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:24,616|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:24,617|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:25,742|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:25,822|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:25,826|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:25,827|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:25,827|INFO|scheduler|push_log|118:
# Waiting for collecting all features from partners ...
# 2023-02-02 08:58:27,157|INFO|scheduler|push_log|118:
# Received features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99
# 2023-02-02 08:58:27,158|DEBUG|scheduler|_switch_status|125:
# self.status='calc_loss'
# 2023-02-02 08:58:27,161|DEBUG|scheduler|_switch_status|125:
# self.status='distribute_grad'
# 2023-02-02 08:58:27,162|INFO|scheduler|push_log|118:
# Distributing features grad tensors ...
# 2023-02-02 08:58:28,292|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:28,365|INFO|scheduler|push_log|118:
# Distributed all features grad tensors to collaborators.
# 2023-02-02 08:58:28,366|DEBUG|scheduler|_switch_status|125:
# self.status='persisting'
# 2023-02-02 08:58:28,369|INFO|scheduler|push_log|118:
# Saved latest parameters locally.
# 2023-02-02 08:58:28,370|INFO|scheduler|push_log|118:
# Saved latest runtime context.
# 2023-02-02 08:58:28,370|DEBUG|scheduler|_switch_status|125:
# self.status='testing'
# 2023-02-02 08:58:28,371|INFO|scheduler|push_log|118:
# Start a round of test.
# 2023-02-02 08:58:28,638|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature'
# 2023-02-02 08:58:28,639|INFO|scheduler|push_log|118:
# Waiting for collecting test dataset features ...
# 2023-02-02 08:58:30,056|INFO|scheduler|push_log|118:
# Received test dataset features from ID: ec72a25c-ff83-47f2-a4bc-74321acace99.
# 2023-02-02 08:58:30,056|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:30,057|INFO|scheduler|push_log|118:
# Fused test data features.
# 2023-02-02 08:58:30,061|INFO|scheduler|push_log|118:
# Complete a round of test.
# 2023-02-02 08:58:30,062|INFO|scheduler|push_log|118:
# Skip or close a round of testing.
# 2023-02-02 08:58:30,073|DEBUG|scheduler|_switch_status|125:
# self.status='closing_round'
# 2023-02-02 08:58:30,086|INFO|scheduler|push_log|118:
# The training of Round 5 complete.
# 2023-02-02 08:58:30,087|DEBUG|scheduler|_switch_status|125:
# self.status='ready'
# 2023-02-02 08:58:30,088|INFO|scheduler|push_log|118:
# Obtained the final results of task 5a8c6b50-6267-4258-afb0-a4e7413ead58
# 2023-02-02 08:58:30,088|DEBUG|scheduler|_switch_status|125:
# self.status='finishing'
# 2023-02-02 08:58:30,089|INFO|scheduler|push_log|118:
# Closing task 5a8c6b50-6267-4258-afb0-a4e7413ead58 ...
# 2023-02-02 08:58:30,089|DEBUG|scheduler|_switch_status|125:
# self.status='finishing'
# 2023-02-02 08:58:30,111|INFO|scheduler|push_log|118:
# Generating task achievement files ...
# 2023-02-02 08:58:30,114|INFO|scheduler|push_log|118:
# Task achievement files are ready.
# 2023-02-02 08:58:30,351|INFO|scheduler|push_log|118:
# Waiting for all collaborators complete their tasks ...
# 2023-02-02 08:58:31,431|INFO|scheduler|push_log|118:
# All collaborators have completed their tasks.
# 2023-02-02 08:58:31,461|INFO|scheduler|push_log|118:
# Task 5a8c6b50-6267-4258-afb0-a4e7413ead58 complete. Byebye!
