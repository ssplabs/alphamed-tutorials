# %%
from hashlib import md5
from typing import List, Set, Tuple

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from cnn_net import HalfConvNet
from torch.utils.data import DataLoader, Subset

from alphafed import logger
from alphafed.hetero_nn import HeteroNNCollaboratorScheduler


class DemoHeteroCollaborator(HeteroNNCollaboratorScheduler):

    def __init__(self,
                 feature_key: str,
                 batch_size: int,
                 schedule_timeout: int = 30,
                 is_feature_trainable: bool = True) -> None:
        super().__init__(feature_key=feature_key,
                         schedule_timeout=schedule_timeout,
                         is_feature_trainable=is_feature_trainable)
        self.batch_size = batch_size

    def load_local_ids(self) -> List[str]:
        # 聚合方取 MNIST 训练样本的前 20000 个、测试样本的前 5000 个，
        # 协作方取 MNIST 训练样本的第 10000 - 30000 个、测试样本的第 3000 - 7000 个.
        # 求交后共有训练样本 10000 个，测试样本 2000 个。
        # 为避免 ID 冲突，测试样本 ID 全部加 100000，以使其和训练样本 ID 不重合
        train_ids = [str(i) for i in range(10000, 30000)]
        test_ids = [str(i) for i in range(103000, 107000)]
        return train_ids + test_ids

    def split_dataset(self, id_intersection: Set[str]) -> Tuple[Set[str], Set[str]]:
        # 示例中训练样本 ID < 100000，测试样本 ID >= 100000，排序后前 10000 个样本为训练样本 ID。
        ids = [int(_id) for _id in id_intersection]
        ids.sort()
        train_ids = ids[:10000]
        test_ids = ids[10000:]

        logger.info(f'Got {len(train_ids)} intersecting samples for training.')
        logger.info(f'Got {len(test_ids)} intersecting samples for testing.')

        return set(train_ids), set(test_ids)

    def build_feature_model(self) -> nn.Module:
        # 现实中每个协作方都可以定义自己的特征模型，不需要与其它任何参与方相同
        return HalfConvNet()

    def build_feature_optimizer(self, feature_model: nn.Module) -> optim.Optimizer:
        # 现实中每个协作方都可以定义自己的优化器，不需要与其它任何参与方相同
        return optim.SGD(feature_model.parameters(), lr=0.01, momentum=0.9)

    def _erase_left(self, _image: torch.Tensor) -> torch.Tensor:
        return _image[:, :, :, 14:]

    def iterate_train_feature(self,
                              feature_model: nn.Module,
                              train_ids: Set[str]) -> torch.Tensor:
        train_dataset = torchvision.datasets.MNIST(
            'data',
            train=True,
            download=True,
            transform=torchvision.transforms.Compose([
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize((0.1307,), (0.3081,))
            ])
        )
        train_ids: List = list(train_ids)
        train_ids.sort(key=lambda x: md5(bytes(x + self.current_round)).digest())

        train_dataset = Subset(train_dataset, train_ids)
        self.train_loader = DataLoader(train_dataset,
                                       batch_size=self.batch_size,
                                       shuffle=False)

        for _data, _ in self.train_loader:  # 丢弃标签数据
            _data = self._erase_left(_data)
            yield feature_model(_data)

    def iterate_test_feature(self,
                             feature_model: nn.Module,
                             test_ids: Set[str]) -> torch.Tensor:
        test_dataset = torchvision.datasets.MNIST(
            'data',
            train=False,
            download=True,
            transform=torchvision.transforms.Compose([
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize((0.1307,), (0.3081,))
            ])
        )
        test_ids = [(i - 100000) for i in test_ids]
        test_dataset = Subset(test_dataset, test_ids)
        self.test_loader = DataLoader(test_dataset,
                                      batch_size=self.batch_size,
                                      shuffle=False)

        for _data, _ in self.test_loader:  # 丢弃标签数据
            _data = self._erase_left(_data)
            yield feature_model(_data)

# %%
from alphafed import mock_context


# 参与方的模拟启动脚本，需要复制到另一个 Notebook 脚本文件中执行
# 与横向联邦不同，异构联邦中 scheduler 实例和聚合方的不一样
scheduler = DemoHeteroCollaborator(
    feature_key='demo_collaborator',
    batch_size=128  # 各个参与方需要设置相同的 batch_size，否则数据无法对齐
)
collaborate_id = 'ec72a25c-ff83-47f2-a4bc-74321acace99'  # 需要与聚合方设置的 ID 一致
task_id = '5a8c6b50-6267-4258-afb0-a4e7413ead58'  # 需要与聚合方设置的 ID 一致
aggregator_id = '9afb99da-2e4c-4676-a434-5f312f583947'  # 需要与聚合方设置的 ID 一致
# 算法实际运行时会从任务管理器获取任务参与节点的 Node ID 列表，但是在模拟环境不能通过
# 访问实际接口获得这个信息，所以需要通过 nodes 参数将这个列表配置在模拟环境中。
with mock_context(id=collaborate_id, nodes=[aggregator_id, collaborate_id]):  # 在模拟调试环境中运行
    # _run 接口是最底层的 Scheduler 接口定义的，横向联邦、异构联邦框架都实现了对应接口
    scheduler._run(id=collaborate_id, task_id=task_id)
# Out:
# 2023-02-02 08:39:44,874|DEBUG|scheduler|_switch_status|125:
# self.status='init'
# 2023-02-02 08:39:44,878|INFO|scheduler|push_log|118:
# Begin to validate local context.
# 2023-02-02 08:39:44,879|INFO|scheduler|push_log|118:
# Local context is ready.
# 2023-02-02 08:39:44,880|INFO|scheduler|push_log|118:
# Node ec72a25c-ff83-47f2-a4bc-74321acace99 is up.
# 2023-02-02 08:39:44,880|DEBUG|scheduler|_switch_status|125:
# self.status='gethoring'
# 2023-02-02 08:39:44,881|INFO|scheduler|push_log|118:
# Checking in the task ...
# 2023-02-02 08:39:44,889|DEBUG|hetero_nn|_check_in|974:
# _wait_for_check_in_response ...
# 2023-02-02 08:39:45,914|INFO|scheduler|push_log|118:
# Node ec72a25c-ff83-47f2-a4bc-74321acace99 have taken part in the task.
# 2023-02-02 08:39:45,915|DEBUG|scheduler|_switch_status|125:
# self.status='ready'
# 2023-02-02 08:39:45,916|DEBUG|scheduler|_switch_status|125:
# self.status='synchronizing'
# 2023-02-02 08:39:45,917|INFO|scheduler|push_log|118:
# Waiting for synchronizing state with the host ...
# 2023-02-02 08:39:45,935|INFO|scheduler|push_log|118:
# Successfully synchronized state with the host.
# 2023-02-02 08:39:45,936|DEBUG|scheduler|_switch_status|125:
# self.status='id_intersection'
# 2023-02-02 08:39:45,943|DEBUG|psi|_switch_status|107:
# self.status='init'
# 2023-02-02 08:39:45,944|DEBUG|psi|_switch_status|107:
# self.status='ready'
# 2023-02-02 08:39:47,126|DEBUG|psi|_switch_status|107:
# self.status='receiving_blind_ids'
# 2023-02-02 08:39:56,159|DEBUG|psi|_switch_status|107:
# self.status='signing'
# 2023-02-02 08:40:05,233|DEBUG|psi|_switch_status|107:
# self.status='sending_signed_ids'
# 2023-02-02 08:40:08,823|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:08,830|DEBUG|psi|_switch_status|107:
# self.status='receiving_intersection'
# 2023-02-02 08:40:16,921|DEBUG|scheduler|_switch_status|125:
# self.status='in_a_round'
# 2023-02-02 08:40:16,922|INFO|scheduler|push_log|118:
# Waiting for training of round 1 begin ...
# 2023-02-02 08:40:16,929|INFO|scheduler|push_log|118:
# Training of round 1 begins.
# 2023-02-02 08:40:16,933|INFO|1830670718|split_dataset|43:
# Got 10000 intersecting samples for training.
# 2023-02-02 08:40:16,933|INFO|1830670718|split_dataset|44:
# Got 2000 intersecting samples for testing.
# 2023-02-02 08:40:17,235|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:17,236|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:17,238|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:17,245|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:18,398|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:18,448|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:18,449|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:18,451|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:19,872|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:19,873|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:19,899|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:19,900|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:19,901|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:20,909|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:22,052|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:22,115|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:22,116|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:22,116|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:22,740|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:22,740|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:22,762|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:22,763|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:22,763|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:23,789|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:24,935|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:24,994|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:24,995|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:24,996|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:26,626|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:26,627|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:26,649|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:26,649|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:26,650|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:27,658|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:28,772|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:28,862|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:28,862|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:28,863|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:30,177|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:30,178|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:30,201|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:30,202|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:30,203|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:31,210|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:32,345|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:32,414|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:32,415|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:32,417|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:33,937|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:33,938|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:33,961|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:33,963|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:33,964|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:33,974|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:35,146|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:35,178|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:35,179|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:35,179|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:36,914|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:36,915|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:36,938|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:36,939|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:36,940|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:36,946|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:38,060|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:38,150|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:38,151|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:38,151|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:38,569|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:38,570|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:38,591|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:38,592|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:38,593|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:39,607|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:40,728|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:40,813|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:40,813|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:40,814|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:41,126|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:41,127|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:41,148|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:41,149|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:41,150|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:42,169|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:43,300|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:43,373|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:43,373|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:43,374|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:44,009|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:44,010|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:44,031|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:44,032|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:44,033|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:45,049|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:46,166|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:46,254|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:46,255|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:46,255|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:46,774|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:46,775|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:46,800|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:46,800|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:46,801|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:47,809|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:48,950|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:49,013|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:49,014|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:49,014|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:49,533|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:49,534|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:49,560|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:49,561|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:49,561|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:50,574|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:51,689|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:51,780|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:51,780|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:51,781|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:52,409|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:52,410|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:52,431|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:52,431|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:52,432|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:53,452|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:54,761|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:54,857|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:54,858|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:54,858|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:56,386|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:56,387|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:56,408|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:56,409|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:56,409|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:56,417|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:40:57,541|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:40:57,621|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:40:57,621|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:40:57,622|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:40:57,934|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:40:57,935|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:40:57,958|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:40:57,959|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:40:57,959|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:40:58,967|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:00,072|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:00,171|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:00,172|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:00,172|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:00,799|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:00,800|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:00,821|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:00,822|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:00,823|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:01,832|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:02,953|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:03,036|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:03,037|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:03,038|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:03,350|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:03,351|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:03,372|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:03,373|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:03,374|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:04,395|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:05,508|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:05,599|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:05,600|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:05,600|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:06,229|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:06,230|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:06,251|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:06,252|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:06,252|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:07,268|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:08,398|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:08,474|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:08,474|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:08,475|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:08,787|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:08,788|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:08,810|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:08,811|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:08,812|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:09,822|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:10,962|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:11,026|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:11,026|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:11,027|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:11,444|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:11,445|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:11,469|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:11,470|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:11,471|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:12,480|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:13,602|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:13,684|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:13,685|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:13,685|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:14,208|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:14,209|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:14,233|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:14,234|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:14,235|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:15,246|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:16,387|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:16,450|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:16,451|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:16,451|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:16,764|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:16,764|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:16,785|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:16,786|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:16,787|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:17,797|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:18,935|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:19,001|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:19,001|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:19,002|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:19,314|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:19,315|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:19,336|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:19,337|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:19,338|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:20,348|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:21,454|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:21,552|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:21,553|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:21,554|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:21,866|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:21,867|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:21,890|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:21,890|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:21,891|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:22,905|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:24,010|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:24,109|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:24,110|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:24,111|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:24,527|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:24,528|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:24,548|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:24,549|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:24,550|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:25,583|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:26,724|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:26,787|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:26,788|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:26,789|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:27,101|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:27,102|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:27,125|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:27,126|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:27,127|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:28,143|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:29,245|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:29,247|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:29,248|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:29,249|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:29,561|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:29,562|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:29,585|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:29,586|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:29,587|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:30,600|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:31,740|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:31,804|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:31,805|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:31,805|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:32,223|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:32,224|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:32,245|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:32,247|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:32,248|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:33,256|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:34,408|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:34,460|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:34,461|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:34,463|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:35,779|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:35,780|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:35,802|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:35,803|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:35,804|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:36,824|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:37,941|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:38,029|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:38,030|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:38,031|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:39,345|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:39,346|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:39,368|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:39,369|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:39,369|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:40,379|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:41,496|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:41,583|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:41,583|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:41,584|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:42,898|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:42,898|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:42,920|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:42,922|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:42,922|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:43,944|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:45,074|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:45,148|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:45,149|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:45,149|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:45,462|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:45,463|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:45,484|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:45,485|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:45,486|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:46,495|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:47,645|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:47,699|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:47,700|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:47,701|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:48,013|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:48,014|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:48,035|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:48,035|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:48,036|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:49,046|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:50,156|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:50,250|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:50,251|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:50,252|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:50,669|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:50,670|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:50,693|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:50,694|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:50,695|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:51,704|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:52,802|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:52,807|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:52,808|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:52,809|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:53,121|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:53,121|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:53,146|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:53,146|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:53,147|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:54,162|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:55,312|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:55,365|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:55,366|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:55,367|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:55,890|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:55,891|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:55,913|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:55,914|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:55,915|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:55,923|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:57,056|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:57,127|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:57,128|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:57,128|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:41:58,442|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:41:58,443|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:41:58,465|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:41:58,466|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:41:58,467|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:41:58,474|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:41:59,600|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:41:59,678|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:41:59,678|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:41:59,679|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:01,000|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:01,001|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:01,024|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:01,025|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:01,025|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:02,036|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:03,198|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:03,240|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:03,241|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:03,243|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:04,662|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:04,666|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:04,687|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:04,689|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:04,689|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:04,700|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:05,843|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:05,904|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:05,905|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:05,905|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:07,325|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:07,326|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:07,348|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:07,349|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:07,350|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:07,365|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:08,476|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:08,569|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:08,569|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:08,570|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:09,884|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:09,884|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:09,908|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:09,909|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:09,910|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:09,922|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:11,044|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:11,126|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:11,127|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:11,129|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:12,549|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:12,550|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:12,574|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:12,574|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:12,575|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:12,587|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:13,735|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:13,791|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:13,792|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:13,792|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:14,104|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:14,105|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:14,127|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:14,128|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:14,129|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:15,139|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:16,260|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:16,343|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:16,344|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:16,345|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:17,659|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:17,660|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:17,681|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:17,683|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:17,683|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:17,692|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:18,794|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:18,796|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:18,796|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:18,797|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:20,111|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:20,112|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:20,133|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:20,134|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:20,135|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:20,148|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:21,281|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:21,352|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:21,353|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:21,354|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:22,668|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:22,669|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:22,692|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:22,693|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:22,694|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:22,700|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:23,841|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:23,904|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:23,905|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:23,906|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:25,219|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:25,220|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:25,242|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:25,243|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:25,244|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:25,260|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:26,398|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:26,464|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:26,465|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:26,465|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:27,884|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:27,885|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:27,908|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:27,910|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:27,910|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:27,916|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:29,052|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:29,120|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:29,121|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:29,121|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:30,435|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:30,436|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:30,460|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:30,460|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:30,461|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:30,474|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:31,618|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:31,678|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:31,678|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:31,679|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:32,989|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:32,990|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:33,011|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:33,012|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:33,013|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:33,042|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:42:34,186|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:42:34,246|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:42:34,247|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:42:34,248|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:42:35,562|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:42:35,563|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:42:35,584|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:42:35,586|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:42:35,587|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:42:35,603|INFO|scheduler|push_log|118:
# Begin to send features.
# ...
# Sending data stream complete.
# 2023-02-02 08:57:43,502|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:43,502|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:43,503|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:43,815|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:43,816|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:43,837|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:43,838|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:43,838|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:57:44,857|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:57:45,972|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:46,061|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:46,062|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:46,062|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:46,375|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:46,375|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:46,398|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:46,399|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:46,400|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:57:47,411|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:57:48,549|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:48,615|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:48,615|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:48,616|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:49,033|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:49,034|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:49,054|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:49,055|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:49,056|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:57:50,070|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:57:51,207|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:51,274|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:51,275|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:51,275|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:51,591|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:51,592|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:51,613|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:51,614|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:51,615|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:57:52,633|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:57:53,746|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:53,837|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:53,838|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:53,838|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:54,256|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:54,257|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:54,279|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:54,281|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:54,281|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:57:55,307|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:57:56,422|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:56,510|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:56,511|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:56,512|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:56,823|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:56,823|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:56,847|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:56,848|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:56,850|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:57:57,859|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:57:58,985|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:57:59,064|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:57:59,064|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:57:59,065|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:57:59,377|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:57:59,378|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:57:59,398|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:57:59,399|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:57:59,400|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:00,414|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:01,505|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:01,518|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:01,519|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:01,521|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:01,831|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:01,832|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:01,857|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:01,858|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:01,858|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:02,868|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:03,969|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:03,973|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:03,973|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:03,974|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:05,293|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:05,294|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:05,315|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:05,316|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:05,317|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:05,326|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:06,451|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:06,530|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:06,531|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:06,533|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:07,841|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:07,843|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:07,879|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:07,880|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:07,881|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:08,899|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:10,045|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:10,103|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:10,104|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:10,105|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:11,416|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:11,417|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:11,440|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:11,441|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:11,443|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:12,451|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:13,576|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:13,655|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:13,656|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:13,657|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:14,969|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:14,970|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:14,990|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:14,991|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:14,991|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:16,005|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:17,129|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:17,211|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:17,212|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:17,212|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:18,528|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:18,529|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:18,550|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:18,551|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:18,551|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:19,559|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:20,673|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:20,763|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:20,764|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:20,766|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:22,080|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:22,081|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:22,106|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:22,107|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:22,108|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:23,120|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:24,244|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:24,324|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:24,325|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:24,326|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:25,640|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:25,641|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:25,649|INFO|scheduler|push_log|118:
# Featured a batch of data.
# 2023-02-02 08:58:25,649|DEBUG|scheduler|_switch_status|125:
# self.status='projecting'
# 2023-02-02 08:58:25,650|INFO|scheduler|push_log|118:
# Waiting for sending features ...
# 2023-02-02 08:58:26,660|INFO|scheduler|push_log|118:
# Begin to send features.
# 2023-02-02 08:58:27,758|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:27,764|INFO|scheduler|push_log|118:
# Sending features complete.
# 2023-02-02 08:58:27,765|DEBUG|scheduler|_switch_status|125:
# self.status='wait_4_feature_grad'
# 2023-02-02 08:58:27,766|INFO|scheduler|push_log|118:
# Waiting for cipher grad of feature model output ...
# 2023-02-02 08:58:28,078|INFO|scheduler|push_log|118:
# Received and decrypted cipher grad of feature model output.
# 2023-02-02 08:58:28,079|DEBUG|scheduler|_switch_status|125:
# self.status='updating'
# 2023-02-02 08:58:28,082|DEBUG|scheduler|_switch_status|125:
# self.status='persisting'
# 2023-02-02 08:58:28,084|INFO|scheduler|push_log|118:
# Saved latest parameters locally.
# 2023-02-02 08:58:28,084|INFO|scheduler|push_log|118:
# Saved latest runtime context.
# 2023-02-02 08:58:28,085|DEBUG|scheduler|_switch_status|125:
# self.status='testing'
# 2023-02-02 08:58:28,086|INFO|scheduler|push_log|118:
# Waiting for start a round of testing ...
# 2023-02-02 08:58:30,482|DEBUG|shared_file_data_channel|_do_send_stream|136:
# Sending data stream complete.
# 2023-02-02 08:58:30,546|INFO|scheduler|push_log|118:
# Sent all batches of feature to the host.
# 2023-02-02 08:58:30,571|INFO|scheduler|push_log|118:
# Skipped or closed a round of testing.
# 2023-02-02 08:58:30,573|DEBUG|scheduler|_switch_status|125:
# self.status='closing_round'
# 2023-02-02 08:58:30,573|INFO|scheduler|push_log|118:
# Waiting for closing signal of training round 5 ...
# 2023-02-02 08:58:30,585|INFO|scheduler|push_log|118:
# ID: ec72a25c-ff83-47f2-a4bc-74321acace99 finished training task of round 5.
# 2023-02-02 08:58:30,585|DEBUG|scheduler|_switch_status|125:
# self.status='ready'
# 2023-02-02 08:58:30,586|DEBUG|scheduler|_switch_status|125:
# self.status='synchronizing'
# 2023-02-02 08:58:30,587|INFO|scheduler|push_log|118:
# Waiting for synchronizing state with the host ...
# 2023-02-02 08:58:30,596|INFO|hetero_nn|_launch_process|959:
# Task complete
# 2023-02-02 08:58:30,597|INFO|scheduler|push_log|118:
# Closing task 5a8c6b50-6267-4258-afb0-a4e7413ead58 ...
# 2023-02-02 08:58:30,598|DEBUG|scheduler|_switch_status|125:
# self.status='finishing'
# 2023-02-02 08:58:30,598|INFO|scheduler|push_log|118:
# Generating task achievement files ...
# 2023-02-02 08:58:30,600|INFO|scheduler|push_log|118:
# Task achievement files are ready.
# 2023-02-02 08:58:30,750|INFO|scheduler|push_log|118:
# Task 5a8c6b50-6267-4258-afb0-a4e7413ead58 complete. Byebye!
