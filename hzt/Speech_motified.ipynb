# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio
import sys

import matplotlib.pyplot as plt
import IPython.display as ipd
from torchaudio.datasets import SPEECHCOMMANDS
import os
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def label_to_index(word):
    # Return the position of the word in labels
    return torch.tensor(labels.index(word))    # 这里就一个数


def index_to_label(index):
    # Return the word corresponding to the index in labels
    # This is the inverse of label_to_index
    return labels[index]
def pad_sequence(batch):
    # Make all tensor in a batch the same length by padding with zeros
    # 用0填充，使一个batch有相同的长度
    batch = [item.t() for item in batch]  # 转置
    batch = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=0.)
    return batch.permute(0, 2, 1)


def collate_fn(batch):

    # A data tuple has the form:
    # waveform, sample_rate, label, speaker_id, utterance_number

    tensors, targets = [], []

    # Gather in lists, and encode labels as indices
    for waveform, _, label, *_ in batch:
        tensors += [waveform]   # 每个波形（tensor类型）加入到列表tensor中
        targets += [label_to_index(label)]

    # Group the list of tensors into a batched tensor
    tensors = pad_sequence(tensors)   # 得到tensor的batch
    targets = torch.stack(targets)  # 连接，在新的维度进行堆叠   得到targets

    return tensors, targets

# %%
class SubsetSC(SPEECHCOMMANDS):
    def __init__(self, path, subset: str = None):
        super().__init__(path, download=False)
# FileNotFoundError: [Errno 2] No such file or directory: './123\\SpeechCommands\\speech_commands_v0.02\\validation_list.txt'
        def load_list(filename):
            filepath = os.path.join(self._path, filename)
#             print(self._path)   # 下划线不会影响使用，通常作为类内提示：用于类内名称
#             print(filepath)
            with open(filepath) as fileobj:   # strip 去掉空格
                return [os.path.normpath(os.path.join(self._path, line.strip())) for line in fileobj]
            # nrompath:规范化路径
        if subset == "validation":
            self._walker = load_list("validation_list.txt")
            print(self._walker)
            print('validation dataset is loaded')
        elif subset == "testing":
            self._walker = load_list("testing_list.txt")
#             print(self._walker)

        if subset == "training":
            excludes = load_list("validation_list.txt") + load_list("testing_list.txt")
            excludes = set(excludes)  # 设置为集合
            self._walker = [w for w in self._walker if w not in excludes]  # 这里排除test和val中的文件。但这里self._walker怎么来的？


            
def create_dataloader(path, batch_size = 256, train = True, shuffle = True, drop_last=False, collate_fn=None):
    # Create training and testing split of the data. We do not use validation in this tutorial.
    if train:
        dataset = SubsetSC(path, "training")
    else:
        dataset = SubsetSC(path, "testing")

    if device == "cuda":
        num_workers = 1
        pin_memory = True
    else:
        num_workers = 0
        pin_memory = False

    dataloader = torch.utils.data.DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        collate_fn=collate_fn,
        drop_last = drop_last,
        num_workers=num_workers,
        pin_memory=pin_memory
    )
#     test_loader = torch.utils.data.DataLoader(
#         test_set,
#         batch_size=batch_size,
#         shuffle=False,
#         drop_last=False,
#         collate_fn=collate_fn,
#         num_workers=num_workers,
#         pin_memory=pin_memory,
#     )

    return dataloader
batch_size = 256

train_loader = create_dataloader(path = './', batch_size = batch_size, train = True, shuffle = True,drop_last = True, collate_fn=collate_fn)


test_loader = create_dataloader(path = './', batch_size = batch_size, train = True, shuffle = False,drop_last = False, collate_fn=collate_fn)

# %%
train_set = SubsetSC('./', "training")  # 用于函数参数传递
waveform, sample_rate, label, speaker_id, utterance_number = train_set[0]
labels = sorted(list(set(datapoint[2] for datapoint in train_set)))  # 所有的类
new_sample_rate = 8000
transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)
transformed = transform(waveform)
class M5(nn.Module):
    def __init__(self, n_input=1, n_output=35, stride=16, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=80, stride=stride)
        self.bn1 = nn.BatchNorm1d(n_channel)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, kernel_size=3)
        self.bn2 = nn.BatchNorm1d(n_channel)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2 * n_channel, kernel_size=3)
        self.bn3 = nn.BatchNorm1d(2 * n_channel)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2 * n_channel, 2 * n_channel, kernel_size=3)
        self.bn4 = nn.BatchNorm1d(2 * n_channel)
        self.pool4 = nn.MaxPool1d(4)
        self.fc1 = nn.Linear(2 * n_channel, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.bn1(x))
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(self.bn2(x))
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(self.bn3(x))
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(self.bn4(x))
        x = self.pool4(x)
        x = F.avg_pool1d(x, x.shape[-1])
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        return F.log_softmax(x, dim=2)


model = M5(n_input=transformed.shape[0], n_output=len(labels))
model.to(device)
print(model)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


n = count_parameters(model)
print("Number of parameters: %s" % n)
# Out:
# M5(
#   (conv1): Conv1d(1, 32, kernel_size=(80,), stride=(16,))
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 32, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(32, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv1d(64, 64, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool4): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=64, out_features=35, bias=True)
# )
# Number of parameters: 26915

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)  # reduce the learning after 20 epochs by a factor of 10

# %%
def train(model, epoch, log_interval):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):   # 这里迭代返回的是data和target

        data = data.to(device)
        target = target.to(device)

        # apply transform and model on whole batch directly on device
        data = transform(data)
        output = model(data)

        # negative log-likelihood for a tensor of size (batch x 1 x n_output)
        loss = F.nll_loss(output.squeeze(), target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # print training stats
        if batch_idx % log_interval == 0:
            print(f"Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}")

        # update progress bar
        pbar.update(pbar_update)
        # record loss
        losses.append(loss.item())

# %%
def number_of_correct(pred, target):
    # count number of correct predictions
    return pred.squeeze().eq(target).sum().item()


def get_likely_index(tensor):   # 匹配最接近的类别
    # find most likely label index for each element in the batch
    return tensor.argmax(dim=-1)


def test(model, epoch):
    model.eval()
    correct = 0
    for data, target in test_loader:

        data = data.to(device)
        target = target.to(device)

        # apply transform and model on whole batch directly on device
        data = transform(data)
        output = model(data)

        pred = get_likely_index(output)
        correct += number_of_correct(pred, target)

        # update progress bar
        pbar.update(pbar_update)

    print(f"\nTest Epoch: {epoch}\tAccuracy: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n")

# %%
log_interval = 20
n_epoch = 5

pbar_update = 1 / (len(train_loader) + len(test_loader))
losses = []

# The transform needs to live on the same device as the model and the data.
transform = transform.to(device)
with tqdm(total=n_epoch) as pbar:
    for epoch in range(1, n_epoch + 1):
        train(model, epoch, log_interval)
        test(model, epoch)
        scheduler.step()

# Let's plot the training loss versus the number of iteration.
plt.plot(losses);
plt.title("training loss");
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s
#     print('tensor.unsqueeze(0)', tensor.unsqueeze(0).shape)
    
    ##########  问题解决   #####################
    tensor = model(tensor.unsqueeze(0))  # 将tensor在0的位置加一个维度，模拟batch_size的值
#     print('model处理后的',tensor.shape)
#     print('model处理后的',tensor)
    tensor = get_likely_index(tensor)   # 得到最可能的一个tensor
    tensor = index_to_label(tensor.squeeze())
    return tensor


waveform, sample_rate, utterance, *_ = train_set[-1]     # 使用train_set的进行预测，这里是为什么？应该使用test的的吧
ipd.Audio(waveform.numpy(), rate=sample_rate)

print(f"Expected: {utterance}. Predicted: {predict(waveform)}.")
# Out:
# Expected: zero. Predicted: zero.

# %%
wrong = 0
right = 0
test_set = SubsetSC('./', "testing")
for i, (waveform, sample_rate, utterance, *_) in enumerate(test_set):
    if waveform.shape[1] != 16000:
        continue
    output = predict(waveform)
    if output != utterance:
        ipd.Audio(waveform.numpy(), rate=sample_rate)
        print(f"#####Data point #{i}. Expected: {utterance}. Predicted: {output}.")
        wrong += 1
        
    else:
#         print("All examples in this dataset were correctly classified!")
#         print("In this case, let's just look at the last data point")
        ipd.Audio(waveform.numpy(), rate=sample_rate)
        right += 1
        print(f"!!!!!Data point #{i}. Expected: {utterance}. Predicted: {output}.")
# Out:
# !!!!!Data point #0. Expected: right. Predicted: right.
# #####Data point #1. Expected: right. Predicted: nine.
# !!!!!Data point #2. Expected: right. Predicted: right.
# !!!!!Data point #4. Expected: right. Predicted: right.
# !!!!!Data point #5. Expected: right. Predicted: right.
# !!!!!Data point #6. Expected: right. Predicted: right.
# !!!!!Data point #7. Expected: right. Predicted: right.
# !!!!!Data point #8. Expected: right. Predicted: right.
# #####Data point #9. Expected: right. Predicted: zero.
# #####Data point #10. Expected: right. Predicted: eight.
# #####Data point #11. Expected: right. Predicted: backward.
# !!!!!Data point #12. Expected: right. Predicted: right.
# !!!!!Data point #13. Expected: right. Predicted: right.
# !!!!!Data point #14. Expected: right. Predicted: right.
# #####Data point #15. Expected: right. Predicted: bed.
# #####Data point #16. Expected: right. Predicted: left.
# #####Data point #17. Expected: right. Predicted: wow.
# !!!!!Data point #18. Expected: right. Predicted: right.
# #####Data point #19. Expected: right. Predicted: five.
# !!!!!Data point #20. Expected: right. Predicted: right.
# !!!!!Data point #21. Expected: right. Predicted: right.
# !!!!!Data point #22. Expected: right. Predicted: right.
# !!!!!Data point #23. Expected: right. Predicted: right.
# !!!!!Data point #24. Expected: right. Predicted: right.
# !!!!!Data point #25. Expected: right. Predicted: right.
# !!!!!Data point #26. Expected: right. Predicted: right.
# !!!!!Data point #28. Expected: right. Predicted: right.
# !!!!!Data point #29. Expected: right. Predicted: right.
# !!!!!Data point #30. Expected: right. Predicted: right.
# !!!!!Data point #31. Expected: right. Predicted: right.
# #####Data point #32. Expected: right. Predicted: backward.
# !!!!!Data point #33. Expected: right. Predicted: right.
# #####Data point #34. Expected: right. Predicted: tree.
# !!!!!Data point #35. Expected: right. Predicted: right.
# !!!!!Data point #37. Expected: right. Predicted: right.
# !!!!!Data point #39. Expected: right. Predicted: right.
# !!!!!Data point #40. Expected: right. Predicted: right.
# !!!!!Data point #41. Expected: right. Predicted: right.
# #####Data point #42. Expected: right. Predicted: bed.
# !!!!!Data point #43. Expected: right. Predicted: right.
# !!!!!Data point #44. Expected: right. Predicted: right.
# !!!!!Data point #45. Expected: right. Predicted: right.
# #####Data point #46. Expected: right. Predicted: left.
# #####Data point #47. Expected: right. Predicted: bed.
# !!!!!Data point #48. Expected: right. Predicted: right.
# !!!!!Data point #49. Expected: right. Predicted: right.
# !!!!!Data point #50. Expected: right. Predicted: right.
# !!!!!Data point #51. Expected: right. Predicted: right.
# !!!!!Data point #52. Expected: right. Predicted: right.
# !!!!!Data point #53. Expected: right. Predicted: right.
# #####Data point #54. Expected: right. Predicted: bed.
# !!!!!Data point #55. Expected: right. Predicted: right.
# !!!!!Data point #56. Expected: right. Predicted: right.
# !!!!!Data point #57. Expected: right. Predicted: right.
# !!!!!Data point #60. Expected: right. Predicted: right.
# !!!!!Data point #61. Expected: right. Predicted: right.
# !!!!!Data point #62. Expected: right. Predicted: right.
# !!!!!Data point #63. Expected: right. Predicted: right.
# #####Data point #64. Expected: right. Predicted: wow.
# !!!!!Data point #65. Expected: right. Predicted: right.
# !!!!!Data point #67. Expected: right. Predicted: right.
# !!!!!Data point #68. Expected: right. Predicted: right.
# !!!!!Data point #69. Expected: right. Predicted: right.
# !!!!!Data point #70. Expected: right. Predicted: right.
# !!!!!Data point #71. Expected: right. Predicted: right.
# #####Data point #72. Expected: right. Predicted: up.
# !!!!!Data point #73. Expected: right. Predicted: right.
# !!!!!Data point #74. Expected: right. Predicted: right.
# !!!!!Data point #75. Expected: right. Predicted: right.
# !!!!!Data point #76. Expected: right. Predicted: right.
# !!!!!Data point #77. Expected: right. Predicted: right.
# !!!!!Data point #78. Expected: right. Predicted: right.
# !!!!!Data point #79. Expected: right. Predicted: right.
# !!!!!Data point #81. Expected: right. Predicted: right.
# !!!!!Data point #82. Expected: right. Predicted: right.
# !!!!!Data point #83. Expected: right. Predicted: right.
# !!!!!Data point #84. Expected: right. Predicted: right.
# #####Data point #86. Expected: right. Predicted: left.
# !!!!!Data point #87. Expected: right. Predicted: right.
# !!!!!Data point #89. Expected: right. Predicted: right.
# !!!!!Data point #90. Expected: right. Predicted: right.
# !!!!!Data point #91. Expected: right. Predicted: right.
# !!!!!Data point #92. Expected: right. Predicted: right.
# #####Data point #93. Expected: right. Predicted: left.
# #####Data point #94. Expected: right. Predicted: bed.
# !!!!!Data point #95. Expected: right. Predicted: right.
# !!!!!Data point #96. Expected: right. Predicted: right.
# !!!!!Data point #97. Expected: right. Predicted: right.
# !!!!!Data point #98. Expected: right. Predicted: right.
# !!!!!Data point #99. Expected: right. Predicted: right.
# !!!!!Data point #100. Expected: right. Predicted: right.
# !!!!!Data point #101. Expected: right. Predicted: right.
# !!!!!Data point #102. Expected: right. Predicted: right.
# !!!!!Data point #103. Expected: right. Predicted: right.
# !!!!!Data point #104. Expected: right. Predicted: right.
# #####Data point #105. Expected: right. Predicted: one.
# !!!!!Data point #106. Expected: right. Predicted: right.
# !!!!!Data point #107. Expected: right. Predicted: right.
# !!!!!Data point #108. Expected: right. Predicted: right.
# !!!!!Data point #109. Expected: right. Predicted: right.
# !!!!!Data point #110. Expected: right. Predicted: right.
# !!!!!Data point #111. Expected: right. Predicted: right.
# !!!!!Data point #112. Expected: right. Predicted: right.
# !!!!!Data point #113. Expected: right. Predicted: right.
# !!!!!Data point #114. Expected: right. Predicted: right.
# !!!!!Data point #115. Expected: right. Predicted: right.
# !!!!!Data point #116. Expected: right. Predicted: right.
# !!!!!Data point #118. Expected: right. Predicted: right.
# !!!!!Data point #119. Expected: right. Predicted: right.
# !!!!!Data point #120. Expected: right. Predicted: right.
# !!!!!Data point #121. Expected: right. Predicted: right.
# !!!!!Data point #122. Expected: right. Predicted: right.
# #####Data point #123. Expected: right. Predicted: eight.
# !!!!!Data point #124. Expected: right. Predicted: right.
# !!!!!Data point #126. Expected: right. Predicted: right.
# !!!!!Data point #127. Expected: right. Predicted: right.
# !!!!!Data point #128. Expected: right. Predicted: right.
# !!!!!Data point #129. Expected: right. Predicted: right.
# !!!!!Data point #130. Expected: right. Predicted: right.
# #####Data point #131. Expected: right. Predicted: bed.
# !!!!!Data point #132. Expected: right. Predicted: right.
# !!!!!Data point #133. Expected: right. Predicted: right.
# !!!!!Data point #135. Expected: right. Predicted: right.
# !!!!!Data point #137. Expected: right. Predicted: right.
# #####Data point #138. Expected: right. Predicted: left.
# !!!!!Data point #139. Expected: right. Predicted: right.
# !!!!!Data point #140. Expected: right. Predicted: right.
# #####Data point #141. Expected: right. Predicted: go.
# !!!!!Data point #142. Expected: right. Predicted: right.
# !!!!!Data point #143. Expected: right. Predicted: right.
# !!!!!Data point #144. Expected: right. Predicted: right.
# !!!!!Data point #145. Expected: right. Predicted: right.
# !!!!!Data point #146. Expected: right. Predicted: right.
# !!!!!Data point #147. Expected: right. Predicted: right.
# #####Data point #148. Expected: right. Predicted: left.
# #####Data point #149. Expected: right. Predicted: yes.
# !!!!!Data point #150. Expected: right. Predicted: right.
# !!!!!Data point #152. Expected: right. Predicted: right.
# !!!!!Data point #153. Expected: right. Predicted: right.
# #####Data point #155. Expected: right. Predicted: left.
# !!!!!Data point #156. Expected: right. Predicted: right.
# !!!!!Data point #157. Expected: right. Predicted: right.
# !!!!!Data point #158. Expected: right. Predicted: right.
# !!!!!Data point #159. Expected: right. Predicted: right.
# !!!!!Data point #160. Expected: right. Predicted: right.
# !!!!!Data point #161. Expected: right. Predicted: right.
# !!!!!Data point #162. Expected: right. Predicted: right.
# !!!!!Data point #163. Expected: right. Predicted: right.
# !!!!!Data point #164. Expected: right. Predicted: right.
# !!!!!Data point #165. Expected: right. Predicted: right.
# !!!!!Data point #166. Expected: right. Predicted: right.
# !!!!!Data point #167. Expected: right. Predicted: right.
# #####Data point #168. Expected: right. Predicted: four.
# !!!!!Data point #169. Expected: right. Predicted: right.
# !!!!!Data point #170. Expected: right. Predicted: right.
# #####Data point #171. Expected: right. Predicted: bird.
# !!!!!Data point #172. Expected: right. Predicted: right.
# #####Data point #173. Expected: right. Predicted: left.
# !!!!!Data point #174. Expected: right. Predicted: right.
# !!!!!Data point #175. Expected: right. Predicted: right.
# !!!!!Data point #176. Expected: right. Predicted: right.
# #####Data point #177. Expected: right. Predicted: up.
# !!!!!Data point #178. Expected: right. Predicted: right.
# !!!!!Data point #179. Expected: right. Predicted: right.
# !!!!!Data point #180. Expected: right. Predicted: right.
# !!!!!Data point #182. Expected: right. Predicted: right.
# !!!!!Data point #184. Expected: right. Predicted: right.
# !!!!!Data point #185. Expected: right. Predicted: right.
# #####Data point #186. Expected: right. Predicted: on.
# !!!!!Data point #187. Expected: right. Predicted: right.
# !!!!!Data point #188. Expected: right. Predicted: right.
# !!!!!Data point #189. Expected: right. Predicted: right.
# !!!!!Data point #190. Expected: right. Predicted: right.
# !!!!!Data point #191. Expected: right. Predicted: right.
# !!!!!Data point #193. Expected: right. Predicted: right.
# !!!!!Data point #194. Expected: right. Predicted: right.
# #####Data point #195. Expected: right. Predicted: wow.
# !!!!!Data point #197. Expected: right. Predicted: right.
# !!!!!Data point #199. Expected: right. Predicted: right.
# #####Data point #200. Expected: right. Predicted: go.
# #####Data point #201. Expected: right. Predicted: five.
# !!!!!Data point #202. Expected: right. Predicted: right.
# #####Data point #203. Expected: right. Predicted: left.
# !!!!!Data point #204. Expected: right. Predicted: right.
# !!!!!Data point #205. Expected: right. Predicted: right.
# !!!!!Data point #206. Expected: right. Predicted: right.
# !!!!!Data point #207. Expected: right. Predicted: right.
# !!!!!Data point #208. Expected: right. Predicted: right.
# #####Data point #209. Expected: right. Predicted: bed.
# !!!!!Data point #210. Expected: right. Predicted: right.
# !!!!!Data point #211. Expected: right. Predicted: right.
# !!!!!Data point #212. Expected: right. Predicted: right.
# !!!!!Data point #213. Expected: right. Predicted: right.
# #####Data point #215. Expected: right. Predicted: up.
# !!!!!Data point #216. Expected: right. Predicted: right.
# !!!!!Data point #217. Expected: right. Predicted: right.
# #####Data point #218. Expected: right. Predicted: five.
# #####Data point #219. Expected: right. Predicted: left.
# !!!!!Data point #220. Expected: right. Predicted: right.
# !!!!!Data point #221. Expected: right. Predicted: right.
# #####Data point #222. Expected: right. Predicted: on.
# !!!!!Data point #223. Expected: right. Predicted: right.
# !!!!!Data point #224. Expected: right. Predicted: right.
# !!!!!Data point #225. Expected: right. Predicted: right.
# !!!!!Data point #226. Expected: right. Predicted: right.
# !!!!!Data point #227. Expected: right. Predicted: right.
# #####Data point #228. Expected: right. Predicted: go.
# !!!!!Data point #229. Expected: right. Predicted: right.
# !!!!!Data point #230. Expected: right. Predicted: right.
# !!!!!Data point #231. Expected: right. Predicted: right.
# !!!!!Data point #232. Expected: right. Predicted: right.
# !!!!!Data point #233. Expected: right. Predicted: right.
# #####Data point #234. Expected: right. Predicted: up.
# !!!!!Data point #235. Expected: right. Predicted: right.
# !!!!!Data point #236. Expected: right. Predicted: right.
# !!!!!Data point #237. Expected: right. Predicted: right.
# !!!!!Data point #238. Expected: right. Predicted: right.
# !!!!!Data point #239. Expected: right. Predicted: right.
# !!!!!Data point #240. Expected: right. Predicted: right.
# #####Data point #241. Expected: right. Predicted: nine.
# !!!!!Data point #242. Expected: right. Predicted: right.
# !!!!!Data point #243. Expected: right. Predicted: right.
# !!!!!Data point #244. Expected: right. Predicted: right.
# !!!!!Data point #245. Expected: right. Predicted: right.
# !!!!!Data point #246. Expected: right. Predicted: right.
# !!!!!Data point #248. Expected: right. Predicted: right.
# !!!!!Data point #249. Expected: right. Predicted: right.
# #####Data point #250. Expected: right. Predicted: backward.
# !!!!!Data point #251. Expected: right. Predicted: right.
# !!!!!Data point #252. Expected: right. Predicted: right.
# #####Data point #253. Expected: right. Predicted: left.
# !!!!!Data point #254. Expected: right. Predicted: right.
# #####Data point #255. Expected: right. Predicted: five.
# !!!!!Data point #256. Expected: right. Predicted: right.
# !!!!!Data point #257. Expected: right. Predicted: right.
# !!!!!Data point #258. Expected: right. Predicted: right.
# !!!!!Data point #261. Expected: right. Predicted: right.
# !!!!!Data point #262. Expected: right. Predicted: right.
# !!!!!Data point #263. Expected: right. Predicted: right.
# !!!!!Data point #264. Expected: right. Predicted: right.
# #####Data point #265. Expected: right. Predicted: up.
# !!!!!Data point #266. Expected: right. Predicted: right.
# !!!!!Data point #267. Expected: right. Predicted: right.
# !!!!!Data point #268. Expected: right. Predicted: right.
# !!!!!Data point #269. Expected: right. Predicted: right.
# #####Data point #270. Expected: right. Predicted: learn.
# !!!!!Data point #271. Expected: right. Predicted: right.
# !!!!!Data point #272. Expected: right. Predicted: right.
# #####Data point #273. Expected: right. Predicted: off.
# !!!!!Data point #274. Expected: right. Predicted: right.
# !!!!!Data point #276. Expected: right. Predicted: right.
# !!!!!Data point #277. Expected: right. Predicted: right.
# !!!!!Data point #278. Expected: right. Predicted: right.
# #####Data point #280. Expected: right. Predicted: five.
# !!!!!Data point #281. Expected: right. Predicted: right.
# !!!!!Data point #282. Expected: right. Predicted: right.
# !!!!!Data point #283. Expected: right. Predicted: right.
# !!!!!Data point #284. Expected: right. Predicted: right.
# !!!!!Data point #285. Expected: right. Predicted: right.
# !!!!!Data point #286. Expected: right. Predicted: right.
# !!!!!Data point #287. Expected: right. Predicted: right.
# !!!!!Data point #288. Expected: right. Predicted: right.
# !!!!!Data point #289. Expected: right. Predicted: right.
# #####Data point #290. Expected: right. Predicted: five.
# !!!!!Data point #291. Expected: right. Predicted: right.
# !!!!!Data point #292. Expected: right. Predicted: right.
# !!!!!Data point #293. Expected: right. Predicted: right.
# #####Data point #294. Expected: right. Predicted: off.
# !!!!!Data point #295. Expected: right. Predicted: right.
# #####Data point #296. Expected: right. Predicted: off.
# !!!!!Data point #297. Expected: right. Predicted: right.
# !!!!!Data point #298. Expected: right. Predicted: right.
# !!!!!Data point #299. Expected: right. Predicted: right.
# !!!!!Data point #300. Expected: right. Predicted: right.
# #####Data point #301. Expected: right. Predicted: left.
# !!!!!Data point #304. Expected: right. Predicted: right.
# !!!!!Data point #305. Expected: right. Predicted: right.
# !!!!!Data point #306. Expected: right. Predicted: right.
# !!!!!Data point #307. Expected: right. Predicted: right.
# !!!!!Data point #308. Expected: right. Predicted: right.
# !!!!!Data point #309. Expected: right. Predicted: right.
# !!!!!Data point #310. Expected: right. Predicted: right.
# #####Data point #312. Expected: right. Predicted: five.
# #####Data point #313. Expected: right. Predicted: nine.
# #####Data point #314. Expected: right. Predicted: backward.
# !!!!!Data point #315. Expected: right. Predicted: right.
# !!!!!Data point #316. Expected: right. Predicted: right.
# #####Data point #317. Expected: right. Predicted: off.
# #####Data point #318. Expected: right. Predicted: nine.
# #####Data point #319. Expected: right. Predicted: learn.
# !!!!!Data point #320. Expected: right. Predicted: right.
# !!!!!Data point #321. Expected: right. Predicted: right.
# !!!!!Data point #322. Expected: right. Predicted: right.
# !!!!!Data point #323. Expected: right. Predicted: right.
# !!!!!Data point #324. Expected: right. Predicted: right.
# #####Data point #325. Expected: right. Predicted: five.
# !!!!!Data point #326. Expected: right. Predicted: right.
# #####Data point #327. Expected: right. Predicted: nine.
# #####Data point #328. Expected: right. Predicted: five.
# #####Data point #329. Expected: right. Predicted: five.
# !!!!!Data point #330. Expected: right. Predicted: right.
# !!!!!Data point #331. Expected: right. Predicted: right.
# !!!!!Data point #332. Expected: right. Predicted: right.
# !!!!!Data point #334. Expected: right. Predicted: right.
# !!!!!Data point #335. Expected: right. Predicted: right.
# !!!!!Data point #336. Expected: right. Predicted: right.
# !!!!!Data point #337. Expected: right. Predicted: right.
# #####Data point #338. Expected: right. Predicted: left.
# #####Data point #339. Expected: right. Predicted: bed.
# !!!!!Data point #340. Expected: right. Predicted: right.
# !!!!!Data point #342. Expected: right. Predicted: right.
# !!!!!Data point #343. Expected: right. Predicted: right.
# !!!!!Data point #344. Expected: right. Predicted: right.
# #####Data point #345. Expected: right. Predicted: five.
# !!!!!Data point #346. Expected: right. Predicted: right.
# !!!!!Data point #347. Expected: right. Predicted: right.
# !!!!!Data point #348. Expected: right. Predicted: right.
# !!!!!Data point #349. Expected: right. Predicted: right.
# #####Data point #350. Expected: right. Predicted: wow.
# #####Data point #351. Expected: right. Predicted: learn.
# #####Data point #352. Expected: right. Predicted: nine.
# !!!!!Data point #353. Expected: right. Predicted: right.
# !!!!!Data point #356. Expected: right. Predicted: right.
# #####Data point #357. Expected: right. Predicted: no.
# !!!!!Data point #358. Expected: right. Predicted: right.
# !!!!!Data point #359. Expected: right. Predicted: right.
# !!!!!Data point #360. Expected: right. Predicted: right.
# !!!!!Data point #361. Expected: right. Predicted: right.
# !!!!!Data point #362. Expected: right. Predicted: right.
# !!!!!Data point #363. Expected: right. Predicted: right.
# !!!!!Data point #364. Expected: right. Predicted: right.
# #####Data point #365. Expected: right. Predicted: five.
# !!!!!Data point #366. Expected: right. Predicted: right.
# !!!!!Data point #367. Expected: right. Predicted: right.
# !!!!!Data point #368. Expected: right. Predicted: right.
# !!!!!Data point #369. Expected: right. Predicted: right.
# !!!!!Data point #370. Expected: right. Predicted: right.
# !!!!!Data point #371. Expected: right. Predicted: right.
# !!!!!Data point #372. Expected: right. Predicted: right.
# !!!!!Data point #373. Expected: right. Predicted: right.
# #####Data point #374. Expected: right. Predicted: cat.
# !!!!!Data point #375. Expected: right. Predicted: right.
# !!!!!Data point #376. Expected: right. Predicted: right.
# !!!!!Data point #377. Expected: right. Predicted: right.
# !!!!!Data point #378. Expected: right. Predicted: right.
# !!!!!Data point #379. Expected: right. Predicted: right.
# !!!!!Data point #380. Expected: right. Predicted: right.
# !!!!!Data point #382. Expected: right. Predicted: right.
# !!!!!Data point #383. Expected: right. Predicted: right.
# !!!!!Data point #384. Expected: right. Predicted: right.
# !!!!!Data point #385. Expected: right. Predicted: right.
# !!!!!Data point #386. Expected: right. Predicted: right.
# !!!!!Data point #387. Expected: right. Predicted: right.
# !!!!!Data point #388. Expected: right. Predicted: right.
# !!!!!Data point #389. Expected: right. Predicted: right.
# !!!!!Data point #390. Expected: right. Predicted: right.
# !!!!!Data point #391. Expected: right. Predicted: right.
# !!!!!Data point #392. Expected: right. Predicted: right.
# #####Data point #393. Expected: right. Predicted: six.
# #####Data point #395. Expected: right. Predicted: learn.
# !!!!!Data point #396. Expected: eight. Predicted: eight.
# #####Data point #397. Expected: eight. Predicted: tree.
# !!!!!Data point #398. Expected: eight. Predicted: eight.
# !!!!!Data point #399. Expected: eight. Predicted: eight.
# !!!!!Data point #400. Expected: eight. Predicted: eight.
# !!!!!Data point #401. Expected: eight. Predicted: eight.
# !!!!!Data point #402. Expected: eight. Predicted: eight.
# !!!!!Data point #403. Expected: eight. Predicted: eight.
# !!!!!Data point #404. Expected: eight. Predicted: eight.
# !!!!!Data point #405. Expected: eight. Predicted: eight.
# !!!!!Data point #406. Expected: eight. Predicted: eight.
# !!!!!Data point #407. Expected: eight. Predicted: eight.
# #####Data point #408. Expected: eight. Predicted: on.
# !!!!!Data point #409. Expected: eight. Predicted: eight.
# !!!!!Data point #410. Expected: eight. Predicted: eight.
# !!!!!Data point #411. Expected: eight. Predicted: eight.
# #####Data point #412. Expected: eight. Predicted: on.
# !!!!!Data point #413. Expected: eight. Predicted: eight.
# !!!!!Data point #414. Expected: eight. Predicted: eight.
# #####Data point #415. Expected: eight. Predicted: two.
# !!!!!Data point #416. Expected: eight. Predicted: eight.
# #####Data point #417. Expected: eight. Predicted: sheila.
# !!!!!Data point #418. Expected: eight. Predicted: eight.
# !!!!!Data point #419. Expected: eight. Predicted: eight.
# #####Data point #420. Expected: eight. Predicted: yes.
# !!!!!Data point #421. Expected: eight. Predicted: eight.
# !!!!!Data point #422. Expected: eight. Predicted: eight.
# !!!!!Data point #423. Expected: eight. Predicted: eight.
# !!!!!Data point #424. Expected: eight. Predicted: eight.
# #####Data point #425. Expected: eight. Predicted: two.
# !!!!!Data point #426. Expected: eight. Predicted: eight.
# #####Data point #427. Expected: eight. Predicted: tree.
# !!!!!Data point #429. Expected: eight. Predicted: eight.
# !!!!!Data point #430. Expected: eight. Predicted: eight.
# #####Data point #431. Expected: eight. Predicted: tree.
# !!!!!Data point #432. Expected: eight. Predicted: eight.
# #####Data point #434. Expected: eight. Predicted: six.
# !!!!!Data point #435. Expected: eight. Predicted: eight.
# !!!!!Data point #436. Expected: eight. Predicted: eight.
# !!!!!Data point #437. Expected: eight. Predicted: eight.
# !!!!!Data point #438. Expected: eight. Predicted: eight.
# !!!!!Data point #439. Expected: eight. Predicted: eight.
# #####Data point #440. Expected: eight. Predicted: six.
# #####Data point #441. Expected: eight. Predicted: two.
# !!!!!Data point #442. Expected: eight. Predicted: eight.
# !!!!!Data point #443. Expected: eight. Predicted: eight.
# !!!!!Data point #444. Expected: eight. Predicted: eight.
# !!!!!Data point #445. Expected: eight. Predicted: eight.
# !!!!!Data point #446. Expected: eight. Predicted: eight.
# !!!!!Data point #447. Expected: eight. Predicted: eight.
# !!!!!Data point #449. Expected: eight. Predicted: eight.
# #####Data point #450. Expected: eight. Predicted: two.
# #####Data point #451. Expected: eight. Predicted: six.
# !!!!!Data point #452. Expected: eight. Predicted: eight.
# #####Data point #453. Expected: eight. Predicted: six.
# #####Data point #454. Expected: eight. Predicted: yes.
# !!!!!Data point #455. Expected: eight. Predicted: eight.
# !!!!!Data point #457. Expected: eight. Predicted: eight.
# !!!!!Data point #458. Expected: eight. Predicted: eight.
# !!!!!Data point #459. Expected: eight. Predicted: eight.
# !!!!!Data point #460. Expected: eight. Predicted: eight.
# !!!!!Data point #461. Expected: eight. Predicted: eight.
# !!!!!Data point #462. Expected: eight. Predicted: eight.
# !!!!!Data point #463. Expected: eight. Predicted: eight.
# !!!!!Data point #464. Expected: eight. Predicted: eight.
# !!!!!Data point #465. Expected: eight. Predicted: eight.
# !!!!!Data point #468. Expected: eight. Predicted: eight.
# !!!!!Data point #469. Expected: eight. Predicted: eight.
# !!!!!Data point #470. Expected: eight. Predicted: eight.
# #####Data point #471. Expected: eight. Predicted: bird.
# #####Data point #472. Expected: eight. Predicted: six.
# !!!!!Data point #473. Expected: eight. Predicted: eight.
# !!!!!Data point #475. Expected: eight. Predicted: eight.
# !!!!!Data point #476. Expected: eight. Predicted: eight.
# !!!!!Data point #477. Expected: eight. Predicted: eight.
# !!!!!Data point #478. Expected: eight. Predicted: eight.
# !!!!!Data point #479. Expected: eight. Predicted: eight.
# !!!!!Data point #480. Expected: eight. Predicted: eight.
# !!!!!Data point #481. Expected: eight. Predicted: eight.
# !!!!!Data point #482. Expected: eight. Predicted: eight.
# !!!!!Data point #483. Expected: eight. Predicted: eight.
# #####Data point #484. Expected: eight. Predicted: stop.
# !!!!!Data point #485. Expected: eight. Predicted: eight.
# !!!!!Data point #486. Expected: eight. Predicted: eight.
# !!!!!Data point #487. Expected: eight. Predicted: eight.
# !!!!!Data point #488. Expected: eight. Predicted: eight.
# !!!!!Data point #491. Expected: eight. Predicted: eight.
# !!!!!Data point #492. Expected: eight. Predicted: eight.
# !!!!!Data point #493. Expected: eight. Predicted: eight.
# !!!!!Data point #494. Expected: eight. Predicted: eight.
# !!!!!Data point #495. Expected: eight. Predicted: eight.
# #####Data point #496. Expected: eight. Predicted: six.
# #####Data point #497. Expected: eight. Predicted: three.
# !!!!!Data point #498. Expected: eight. Predicted: eight.
# #####Data point #499. Expected: eight. Predicted: left.
# !!!!!Data point #500. Expected: eight. Predicted: eight.
# !!!!!Data point #501. Expected: eight. Predicted: eight.
# #####Data point #502. Expected: eight. Predicted: three.
# !!!!!Data point #503. Expected: eight. Predicted: eight.
# !!!!!Data point #504. Expected: eight. Predicted: eight.
# !!!!!Data point #505. Expected: eight. Predicted: eight.
# !!!!!Data point #506. Expected: eight. Predicted: eight.
# !!!!!Data point #507. Expected: eight. Predicted: eight.
# !!!!!Data point #508. Expected: eight. Predicted: eight.
# !!!!!Data point #509. Expected: eight. Predicted: eight.
# !!!!!Data point #510. Expected: eight. Predicted: eight.
# #####Data point #511. Expected: eight. Predicted: six.
# #####Data point #512. Expected: eight. Predicted: two.
# #####Data point #513. Expected: eight. Predicted: zero.
# !!!!!Data point #514. Expected: eight. Predicted: eight.
# !!!!!Data point #515. Expected: eight. Predicted: eight.
# !!!!!Data point #516. Expected: eight. Predicted: eight.
# !!!!!Data point #517. Expected: eight. Predicted: eight.
# !!!!!Data point #518. Expected: eight. Predicted: eight.
# !!!!!Data point #519. Expected: eight. Predicted: eight.
# !!!!!Data point #520. Expected: eight. Predicted: eight.
# !!!!!Data point #521. Expected: eight. Predicted: eight.
# !!!!!Data point #522. Expected: eight. Predicted: eight.
# !!!!!Data point #523. Expected: eight. Predicted: eight.
# !!!!!Data point #524. Expected: eight. Predicted: eight.
# !!!!!Data point #525. Expected: eight. Predicted: eight.
# !!!!!Data point #526. Expected: eight. Predicted: eight.
# !!!!!Data point #527. Expected: eight. Predicted: eight.
# !!!!!Data point #528. Expected: eight. Predicted: eight.
# !!!!!Data point #529. Expected: eight. Predicted: eight.
# !!!!!Data point #530. Expected: eight. Predicted: eight.
# !!!!!Data point #531. Expected: eight. Predicted: eight.
# !!!!!Data point #532. Expected: eight. Predicted: eight.
# !!!!!Data point #533. Expected: eight. Predicted: eight.
# !!!!!Data point #534. Expected: eight. Predicted: eight.
# !!!!!Data point #535. Expected: eight. Predicted: eight.
# !!!!!Data point #537. Expected: eight. Predicted: eight.
# !!!!!Data point #538. Expected: eight. Predicted: eight.
# !!!!!Data point #539. Expected: eight. Predicted: eight.
# !!!!!Data point #540. Expected: eight. Predicted: eight.
# !!!!!Data point #541. Expected: eight. Predicted: eight.
# !!!!!Data point #542. Expected: eight. Predicted: eight.
# !!!!!Data point #543. Expected: eight. Predicted: eight.
# !!!!!Data point #544. Expected: eight. Predicted: eight.
# !!!!!Data point #545. Expected: eight. Predicted: eight.
# !!!!!Data point #546. Expected: eight. Predicted: eight.
# !!!!!Data point #547. Expected: eight. Predicted: eight.
# !!!!!Data point #549. Expected: eight. Predicted: eight.
# !!!!!Data point #550. Expected: eight. Predicted: eight.
# !!!!!Data point #551. Expected: eight. Predicted: eight.
# !!!!!Data point #552. Expected: eight. Predicted: eight.
# #####Data point #553. Expected: eight. Predicted: four.
# !!!!!Data point #554. Expected: eight. Predicted: eight.
# !!!!!Data point #555. Expected: eight. Predicted: eight.
# !!!!!Data point #556. Expected: eight. Predicted: eight.
# !!!!!Data point #558. Expected: eight. Predicted: eight.
# #####Data point #560. Expected: eight. Predicted: three.
# !!!!!Data point #561. Expected: eight. Predicted: eight.
# #####Data point #562. Expected: eight. Predicted: six.
# #####Data point #563. Expected: eight. Predicted: tree.
# #####Data point #564. Expected: eight. Predicted: two.
# !!!!!Data point #565. Expected: eight. Predicted: eight.
# !!!!!Data point #566. Expected: eight. Predicted: eight.
# !!!!!Data point #567. Expected: eight. Predicted: eight.
# !!!!!Data point #568. Expected: eight. Predicted: eight.
# !!!!!Data point #569. Expected: eight. Predicted: eight.
# !!!!!Data point #570. Expected: eight. Predicted: eight.
# !!!!!Data point #571. Expected: eight. Predicted: eight.
# !!!!!Data point #572. Expected: eight. Predicted: eight.
# !!!!!Data point #573. Expected: eight. Predicted: eight.
# !!!!!Data point #574. Expected: eight. Predicted: eight.
# #####Data point #575. Expected: eight. Predicted: yes.
# !!!!!Data point #576. Expected: eight. Predicted: eight.
# !!!!!Data point #577. Expected: eight. Predicted: eight.
# !!!!!Data point #578. Expected: eight. Predicted: eight.
# !!!!!Data point #579. Expected: eight. Predicted: eight.
# !!!!!Data point #580. Expected: eight. Predicted: eight.
# !!!!!Data point #581. Expected: eight. Predicted: eight.
# !!!!!Data point #582. Expected: eight. Predicted: eight.
# !!!!!Data point #583. Expected: eight. Predicted: eight.
# !!!!!Data point #584. Expected: eight. Predicted: eight.
# #####Data point #585. Expected: eight. Predicted: six.
# !!!!!Data point #586. Expected: eight. Predicted: eight.
# !!!!!Data point #587. Expected: eight. Predicted: eight.
# !!!!!Data point #588. Expected: eight. Predicted: eight.
# !!!!!Data point #589. Expected: eight. Predicted: eight.
# !!!!!Data point #590. Expected: eight. Predicted: eight.
# !!!!!Data point #591. Expected: eight. Predicted: eight.
# #####Data point #592. Expected: eight. Predicted: zero.
# #####Data point #593. Expected: eight. Predicted: bird.
# !!!!!Data point #594. Expected: eight. Predicted: eight.
# !!!!!Data point #595. Expected: eight. Predicted: eight.
# !!!!!Data point #596. Expected: eight. Predicted: eight.
# !!!!!Data point #597. Expected: eight. Predicted: eight.
# !!!!!Data point #598. Expected: eight. Predicted: eight.
# !!!!!Data point #599. Expected: eight. Predicted: eight.
# !!!!!Data point #600. Expected: eight. Predicted: eight.
# !!!!!Data point #601. Expected: eight. Predicted: eight.
# #####Data point #602. Expected: eight. Predicted: stop.
# !!!!!Data point #603. Expected: eight. Predicted: eight.
# !!!!!Data point #604. Expected: eight. Predicted: eight.
# #####Data point #605. Expected: eight. Predicted: two.
# !!!!!Data point #606. Expected: eight. Predicted: eight.
# !!!!!Data point #607. Expected: eight. Predicted: eight.
# #####Data point #608. Expected: eight. Predicted: right.
# !!!!!Data point #609. Expected: eight. Predicted: eight.
# !!!!!Data point #610. Expected: eight. Predicted: eight.
# #####Data point #611. Expected: eight. Predicted: six.
# #####Data point #612. Expected: eight. Predicted: two.
# !!!!!Data point #613. Expected: eight. Predicted: eight.
# !!!!!Data point #614. Expected: eight. Predicted: eight.
# !!!!!Data point #615. Expected: eight. Predicted: eight.
# !!!!!Data point #616. Expected: eight. Predicted: eight.
# !!!!!Data point #617. Expected: eight. Predicted: eight.
# !!!!!Data point #618. Expected: eight. Predicted: eight.
# !!!!!Data point #620. Expected: eight. Predicted: eight.
# !!!!!Data point #621. Expected: eight. Predicted: eight.
# #####Data point #622. Expected: eight. Predicted: three.
# #####Data point #623. Expected: eight. Predicted: three.
# !!!!!Data point #624. Expected: eight. Predicted: eight.
# #####Data point #625. Expected: eight. Predicted: three.
# !!!!!Data point #626. Expected: eight. Predicted: eight.
# !!!!!Data point #627. Expected: eight. Predicted: eight.
# !!!!!Data point #628. Expected: eight. Predicted: eight.
# !!!!!Data point #629. Expected: eight. Predicted: eight.
# !!!!!Data point #630. Expected: eight. Predicted: eight.
# !!!!!Data point #631. Expected: eight. Predicted: eight.
# !!!!!Data point #632. Expected: eight. Predicted: eight.
# #####Data point #633. Expected: eight. Predicted: six.
# !!!!!Data point #634. Expected: eight. Predicted: eight.
# !!!!!Data point #635. Expected: eight. Predicted: eight.
# #####Data point #636. Expected: eight. Predicted: left.
# !!!!!Data point #637. Expected: eight. Predicted: eight.
# !!!!!Data point #638. Expected: eight. Predicted: eight.
# #####Data point #639. Expected: eight. Predicted: six.
# !!!!!Data point #640. Expected: eight. Predicted: eight.
# !!!!!Data point #641. Expected: eight. Predicted: eight.
# !!!!!Data point #642. Expected: eight. Predicted: eight.
# !!!!!Data point #643. Expected: eight. Predicted: eight.
# !!!!!Data point #644. Expected: eight. Predicted: eight.
# !!!!!Data point #645. Expected: eight. Predicted: eight.
# !!!!!Data point #646. Expected: eight. Predicted: eight.
# !!!!!Data point #647. Expected: eight. Predicted: eight.
# #####Data point #648. Expected: eight. Predicted: bird.
# #####Data point #649. Expected: eight. Predicted: three.
# !!!!!Data point #650. Expected: eight. Predicted: eight.
# !!!!!Data point #651. Expected: eight. Predicted: eight.
# !!!!!Data point #652. Expected: eight. Predicted: eight.
# #####Data point #653. Expected: eight. Predicted: dog.
# #####Data point #654. Expected: eight. Predicted: on.
# !!!!!Data point #655. Expected: eight. Predicted: eight.
# !!!!!Data point #656. Expected: eight. Predicted: eight.
# !!!!!Data point #657. Expected: eight. Predicted: eight.
# !!!!!Data point #658. Expected: eight. Predicted: eight.
# !!!!!Data point #659. Expected: eight. Predicted: eight.
# #####Data point #660. Expected: eight. Predicted: six.
# !!!!!Data point #661. Expected: eight. Predicted: eight.
# !!!!!Data point #662. Expected: eight. Predicted: eight.
# !!!!!Data point #663. Expected: eight. Predicted: eight.
# #####Data point #664. Expected: eight. Predicted: left.
# !!!!!Data point #665. Expected: eight. Predicted: eight.
# !!!!!Data point #666. Expected: eight. Predicted: eight.
# !!!!!Data point #667. Expected: eight. Predicted: eight.
# #####Data point #668. Expected: eight. Predicted: yes.
# #####Data point #669. Expected: eight. Predicted: three.
# !!!!!Data point #670. Expected: eight. Predicted: eight.
# !!!!!Data point #671. Expected: eight. Predicted: eight.
# !!!!!Data point #672. Expected: eight. Predicted: eight.
# !!!!!Data point #673. Expected: eight. Predicted: eight.
# !!!!!Data point #674. Expected: eight. Predicted: eight.
# !!!!!Data point #675. Expected: eight. Predicted: eight.
# !!!!!Data point #677. Expected: eight. Predicted: eight.
# #####Data point #678. Expected: eight. Predicted: bird.
# !!!!!Data point #679. Expected: eight. Predicted: eight.
# !!!!!Data point #680. Expected: eight. Predicted: eight.
# !!!!!Data point #681. Expected: eight. Predicted: eight.
# !!!!!Data point #682. Expected: eight. Predicted: eight.
# !!!!!Data point #683. Expected: eight. Predicted: eight.
# #####Data point #684. Expected: eight. Predicted: three.
# !!!!!Data point #685. Expected: eight. Predicted: eight.
# #####Data point #686. Expected: eight. Predicted: visual.
# !!!!!Data point #687. Expected: eight. Predicted: eight.
# !!!!!Data point #688. Expected: eight. Predicted: eight.
# !!!!!Data point #689. Expected: eight. Predicted: eight.
# !!!!!Data point #690. Expected: eight. Predicted: eight.
# !!!!!Data point #691. Expected: eight. Predicted: eight.
# #####Data point #692. Expected: eight. Predicted: three.
# !!!!!Data point #693. Expected: eight. Predicted: eight.
# !!!!!Data point #695. Expected: eight. Predicted: eight.
# !!!!!Data point #696. Expected: eight. Predicted: eight.
# !!!!!Data point #697. Expected: eight. Predicted: eight.
# !!!!!Data point #699. Expected: eight. Predicted: eight.
# #####Data point #700. Expected: eight. Predicted: six.
# !!!!!Data point #701. Expected: eight. Predicted: eight.
# #####Data point #702. Expected: eight. Predicted: six.
# !!!!!Data point #704. Expected: eight. Predicted: eight.
# #####Data point #705. Expected: eight. Predicted: tree.
# !!!!!Data point #706. Expected: eight. Predicted: eight.
# !!!!!Data point #707. Expected: eight. Predicted: eight.
# #####Data point #708. Expected: eight. Predicted: four.
# !!!!!Data point #709. Expected: eight. Predicted: eight.
# #####Data point #710. Expected: eight. Predicted: bed.
# !!!!!Data point #711. Expected: eight. Predicted: eight.
# !!!!!Data point #712. Expected: eight. Predicted: eight.
# !!!!!Data point #713. Expected: eight. Predicted: eight.
# !!!!!Data point #714. Expected: eight. Predicted: eight.
# !!!!!Data point #715. Expected: eight. Predicted: eight.
# !!!!!Data point #719. Expected: eight. Predicted: eight.
# !!!!!Data point #720. Expected: eight. Predicted: eight.
# !!!!!Data point #721. Expected: eight. Predicted: eight.
# !!!!!Data point #722. Expected: eight. Predicted: eight.
# !!!!!Data point #726. Expected: eight. Predicted: eight.
# !!!!!Data point #727. Expected: eight. Predicted: eight.
# #####Data point #728. Expected: eight. Predicted: bed.
# !!!!!Data point #729. Expected: eight. Predicted: eight.
# !!!!!Data point #730. Expected: eight. Predicted: eight.
# !!!!!Data point #731. Expected: eight. Predicted: eight.
# !!!!!Data point #732. Expected: eight. Predicted: eight.
# !!!!!Data point #733. Expected: eight. Predicted: eight.
# !!!!!Data point #734. Expected: eight. Predicted: eight.
# !!!!!Data point #735. Expected: eight. Predicted: eight.
# !!!!!Data point #737. Expected: eight. Predicted: eight.
# !!!!!Data point #738. Expected: eight. Predicted: eight.
# !!!!!Data point #739. Expected: eight. Predicted: eight.
# !!!!!Data point #740. Expected: eight. Predicted: eight.
# !!!!!Data point #741. Expected: eight. Predicted: eight.
# !!!!!Data point #742. Expected: eight. Predicted: eight.
# !!!!!Data point #743. Expected: eight. Predicted: eight.
# !!!!!Data point #744. Expected: eight. Predicted: eight.
# !!!!!Data point #746. Expected: eight. Predicted: eight.
# #####Data point #747. Expected: eight. Predicted: six.
# !!!!!Data point #748. Expected: eight. Predicted: eight.
# #####Data point #750. Expected: eight. Predicted: two.
# !!!!!Data point #751. Expected: eight. Predicted: eight.
# !!!!!Data point #752. Expected: eight. Predicted: eight.
# !!!!!Data point #753. Expected: eight. Predicted: eight.
# !!!!!Data point #754. Expected: eight. Predicted: eight.
# !!!!!Data point #756. Expected: eight. Predicted: eight.
# !!!!!Data point #757. Expected: eight. Predicted: eight.
# !!!!!Data point #758. Expected: eight. Predicted: eight.
# !!!!!Data point #759. Expected: eight. Predicted: eight.
# !!!!!Data point #760. Expected: eight. Predicted: eight.
# !!!!!Data point #761. Expected: eight. Predicted: eight.
# !!!!!Data point #762. Expected: eight. Predicted: eight.
# !!!!!Data point #763. Expected: eight. Predicted: eight.
# !!!!!Data point #764. Expected: eight. Predicted: eight.
# !!!!!Data point #765. Expected: eight. Predicted: eight.
# !!!!!Data point #766. Expected: eight. Predicted: eight.
# !!!!!Data point #768. Expected: eight. Predicted: eight.
# !!!!!Data point #769. Expected: eight. Predicted: eight.
# !!!!!Data point #770. Expected: eight. Predicted: eight.
# #####Data point #771. Expected: eight. Predicted: yes.
# #####Data point #772. Expected: eight. Predicted: up.
# !!!!!Data point #773. Expected: eight. Predicted: eight.
# !!!!!Data point #774. Expected: eight. Predicted: eight.
# !!!!!Data point #775. Expected: eight. Predicted: eight.
# !!!!!Data point #776. Expected: eight. Predicted: eight.
# !!!!!Data point #777. Expected: eight. Predicted: eight.
# !!!!!Data point #778. Expected: eight. Predicted: eight.
# !!!!!Data point #779. Expected: eight. Predicted: eight.
# !!!!!Data point #780. Expected: eight. Predicted: eight.
# #####Data point #781. Expected: eight. Predicted: tree.
# #####Data point #782. Expected: eight. Predicted: six.
# !!!!!Data point #783. Expected: eight. Predicted: eight.
# !!!!!Data point #784. Expected: eight. Predicted: eight.
# !!!!!Data point #785. Expected: eight. Predicted: eight.
# !!!!!Data point #786. Expected: eight. Predicted: eight.
# !!!!!Data point #787. Expected: eight. Predicted: eight.
# !!!!!Data point #789. Expected: eight. Predicted: eight.
# !!!!!Data point #790. Expected: eight. Predicted: eight.
# !!!!!Data point #791. Expected: eight. Predicted: eight.
# !!!!!Data point #792. Expected: eight. Predicted: eight.
# !!!!!Data point #793. Expected: eight. Predicted: eight.
# !!!!!Data point #794. Expected: eight. Predicted: eight.
# !!!!!Data point #795. Expected: eight. Predicted: eight.
# !!!!!Data point #797. Expected: eight. Predicted: eight.
# !!!!!Data point #798. Expected: eight. Predicted: eight.
# !!!!!Data point #799. Expected: eight. Predicted: eight.
# !!!!!Data point #801. Expected: eight. Predicted: eight.
# #####Data point #802. Expected: eight. Predicted: off.
# #####Data point #803. Expected: eight. Predicted: tree.
# !!!!!Data point #804. Expected: cat. Predicted: cat.
# #####Data point #805. Expected: cat. Predicted: stop.
# #####Data point #806. Expected: cat. Predicted: up.
# !!!!!Data point #807. Expected: cat. Predicted: cat.
# #####Data point #808. Expected: cat. Predicted: six.
# #####Data point #809. Expected: cat. Predicted: stop.
# !!!!!Data point #810. Expected: cat. Predicted: cat.
# !!!!!Data point #811. Expected: cat. Predicted: cat.
# !!!!!Data point #812. Expected: cat. Predicted: cat.
# !!!!!Data point #813. Expected: cat. Predicted: cat.
# !!!!!Data point #814. Expected: cat. Predicted: cat.
# #####Data point #815. Expected: cat. Predicted: eight.
# #####Data point #816. Expected: cat. Predicted: bed.
# #####Data point #817. Expected: cat. Predicted: tree.
# !!!!!Data point #818. Expected: cat. Predicted: cat.
# !!!!!Data point #819. Expected: cat. Predicted: cat.
# !!!!!Data point #820. Expected: cat. Predicted: cat.
# #####Data point #822. Expected: cat. Predicted: yes.
# #####Data point #823. Expected: cat. Predicted: stop.
# !!!!!Data point #824. Expected: cat. Predicted: cat.
# !!!!!Data point #825. Expected: cat. Predicted: cat.
# !!!!!Data point #826. Expected: cat. Predicted: cat.
# !!!!!Data point #827. Expected: cat. Predicted: cat.
# !!!!!Data point #829. Expected: cat. Predicted: cat.
# !!!!!Data point #830. Expected: cat. Predicted: cat.
# !!!!!Data point #831. Expected: cat. Predicted: cat.
# !!!!!Data point #832. Expected: cat. Predicted: cat.
# !!!!!Data point #833. Expected: cat. Predicted: cat.
# !!!!!Data point #834. Expected: cat. Predicted: cat.
# !!!!!Data point #835. Expected: cat. Predicted: cat.
# !!!!!Data point #836. Expected: cat. Predicted: cat.
# !!!!!Data point #837. Expected: cat. Predicted: cat.
# !!!!!Data point #838. Expected: cat. Predicted: cat.
# !!!!!Data point #839. Expected: cat. Predicted: cat.
# !!!!!Data point #840. Expected: cat. Predicted: cat.
# !!!!!Data point #842. Expected: cat. Predicted: cat.
# !!!!!Data point #843. Expected: cat. Predicted: cat.
# !!!!!Data point #844. Expected: cat. Predicted: cat.
# !!!!!Data point #845. Expected: cat. Predicted: cat.
# !!!!!Data point #847. Expected: cat. Predicted: cat.
# !!!!!Data point #848. Expected: cat. Predicted: cat.
# !!!!!Data point #849. Expected: cat. Predicted: cat.
# !!!!!Data point #850. Expected: cat. Predicted: cat.
# #####Data point #851. Expected: cat. Predicted: stop.
# !!!!!Data point #852. Expected: cat. Predicted: cat.
# !!!!!Data point #853. Expected: cat. Predicted: cat.
# !!!!!Data point #854. Expected: cat. Predicted: cat.
# !!!!!Data point #855. Expected: cat. Predicted: cat.
# !!!!!Data point #856. Expected: cat. Predicted: cat.
# !!!!!Data point #857. Expected: cat. Predicted: cat.
# !!!!!Data point #858. Expected: cat. Predicted: cat.
# !!!!!Data point #859. Expected: cat. Predicted: cat.
# !!!!!Data point #860. Expected: cat. Predicted: cat.
# !!!!!Data point #861. Expected: cat. Predicted: cat.
# !!!!!Data point #862. Expected: cat. Predicted: cat.
# !!!!!Data point #863. Expected: cat. Predicted: cat.
# #####Data point #864. Expected: cat. Predicted: up.
# !!!!!Data point #865. Expected: cat. Predicted: cat.
# !!!!!Data point #866. Expected: cat. Predicted: cat.
# !!!!!Data point #867. Expected: cat. Predicted: cat.
# #####Data point #868. Expected: cat. Predicted: tree.
# #####Data point #869. Expected: cat. Predicted: happy.
# !!!!!Data point #870. Expected: cat. Predicted: cat.
# !!!!!Data point #871. Expected: cat. Predicted: cat.
# !!!!!Data point #873. Expected: cat. Predicted: cat.
# !!!!!Data point #875. Expected: cat. Predicted: cat.
# !!!!!Data point #876. Expected: cat. Predicted: cat.
# !!!!!Data point #877. Expected: cat. Predicted: cat.
# #####Data point #878. Expected: cat. Predicted: tree.
# !!!!!Data point #879. Expected: cat. Predicted: cat.
# !!!!!Data point #882. Expected: cat. Predicted: cat.
# !!!!!Data point #883. Expected: cat. Predicted: cat.
# !!!!!Data point #884. Expected: cat. Predicted: cat.
# !!!!!Data point #885. Expected: cat. Predicted: cat.
# !!!!!Data point #886. Expected: cat. Predicted: cat.
# #####Data point #887. Expected: cat. Predicted: house.
# !!!!!Data point #889. Expected: cat. Predicted: cat.
# !!!!!Data point #890. Expected: cat. Predicted: cat.
# !!!!!Data point #891. Expected: cat. Predicted: cat.
# #####Data point #892. Expected: cat. Predicted: up.
# !!!!!Data point #894. Expected: cat. Predicted: cat.
# !!!!!Data point #895. Expected: cat. Predicted: cat.
# !!!!!Data point #897. Expected: cat. Predicted: cat.
# !!!!!Data point #898. Expected: cat. Predicted: cat.
# !!!!!Data point #899. Expected: cat. Predicted: cat.
# !!!!!Data point #900. Expected: cat. Predicted: cat.
# !!!!!Data point #901. Expected: cat. Predicted: cat.
# !!!!!Data point #902. Expected: cat. Predicted: cat.
# #####Data point #903. Expected: cat. Predicted: six.
# #####Data point #904. Expected: cat. Predicted: stop.
# !!!!!Data point #905. Expected: cat. Predicted: cat.
# !!!!!Data point #906. Expected: cat. Predicted: cat.
# !!!!!Data point #907. Expected: cat. Predicted: cat.
# !!!!!Data point #908. Expected: cat. Predicted: cat.
# #####Data point #909. Expected: cat. Predicted: six.
# #####Data point #910. Expected: cat. Predicted: one.
# !!!!!Data point #911. Expected: cat. Predicted: cat.
# !!!!!Data point #912. Expected: cat. Predicted: cat.
# #####Data point #913. Expected: cat. Predicted: up.
# !!!!!Data point #914. Expected: cat. Predicted: cat.
# !!!!!Data point #915. Expected: cat. Predicted: cat.
# !!!!!Data point #916. Expected: cat. Predicted: cat.
# !!!!!Data point #917. Expected: cat. Predicted: cat.
# #####Data point #918. Expected: cat. Predicted: stop.
# !!!!!Data point #919. Expected: cat. Predicted: cat.
# #####Data point #920. Expected: cat. Predicted: left.
# #####Data point #922. Expected: cat. Predicted: six.
# #####Data point #923. Expected: cat. Predicted: one.
# !!!!!Data point #924. Expected: cat. Predicted: cat.
# !!!!!Data point #925. Expected: cat. Predicted: cat.
# !!!!!Data point #926. Expected: cat. Predicted: cat.
# !!!!!Data point #928. Expected: cat. Predicted: cat.
# !!!!!Data point #929. Expected: cat. Predicted: cat.
# !!!!!Data point #930. Expected: cat. Predicted: cat.
# !!!!!Data point #931. Expected: cat. Predicted: cat.
# !!!!!Data point #932. Expected: cat. Predicted: cat.
# !!!!!Data point #933. Expected: cat. Predicted: cat.
# !!!!!Data point #934. Expected: cat. Predicted: cat.
# !!!!!Data point #936. Expected: cat. Predicted: cat.
# ...
# #####Data point #10699. Expected: four. Predicted: sheila.
# !!!!!Data point #10700. Expected: four. Predicted: four.
# !!!!!Data point #10701. Expected: four. Predicted: four.
# !!!!!Data point #10702. Expected: four. Predicted: four.
# !!!!!Data point #10703. Expected: four. Predicted: four.
# !!!!!Data point #10704. Expected: four. Predicted: four.
# !!!!!Data point #10705. Expected: four. Predicted: four.
# !!!!!Data point #10706. Expected: four. Predicted: four.
# !!!!!Data point #10707. Expected: four. Predicted: four.
# !!!!!Data point #10708. Expected: four. Predicted: four.
# !!!!!Data point #10709. Expected: four. Predicted: four.
# #####Data point #10710. Expected: four. Predicted: zero.
# !!!!!Data point #10711. Expected: four. Predicted: four.
# #####Data point #10712. Expected: four. Predicted: forward.
# !!!!!Data point #10713. Expected: four. Predicted: four.
# !!!!!Data point #10714. Expected: four. Predicted: four.
# !!!!!Data point #10715. Expected: four. Predicted: four.
# !!!!!Data point #10716. Expected: four. Predicted: four.
# #####Data point #10717. Expected: four. Predicted: forward.
# !!!!!Data point #10718. Expected: four. Predicted: four.
# !!!!!Data point #10719. Expected: four. Predicted: four.
# !!!!!Data point #10720. Expected: four. Predicted: four.
# !!!!!Data point #10721. Expected: four. Predicted: four.
# !!!!!Data point #10722. Expected: four. Predicted: four.
# !!!!!Data point #10723. Expected: four. Predicted: four.
# !!!!!Data point #10724. Expected: four. Predicted: four.
# !!!!!Data point #10725. Expected: four. Predicted: four.
# !!!!!Data point #10726. Expected: four. Predicted: four.
# #####Data point #10727. Expected: four. Predicted: yes.
# !!!!!Data point #10728. Expected: four. Predicted: four.
# !!!!!Data point #10729. Expected: four. Predicted: four.
# !!!!!Data point #10730. Expected: four. Predicted: four.
# !!!!!Data point #10732. Expected: four. Predicted: four.
# !!!!!Data point #10733. Expected: four. Predicted: four.
# !!!!!Data point #10735. Expected: four. Predicted: four.
# #####Data point #10736. Expected: four. Predicted: up.
# !!!!!Data point #10737. Expected: four. Predicted: four.
# !!!!!Data point #10738. Expected: four. Predicted: four.
# !!!!!Data point #10739. Expected: four. Predicted: four.
# !!!!!Data point #10740. Expected: four. Predicted: four.
# !!!!!Data point #10741. Expected: four. Predicted: four.
# !!!!!Data point #10742. Expected: four. Predicted: four.
# !!!!!Data point #10743. Expected: four. Predicted: four.
# !!!!!Data point #10745. Expected: four. Predicted: four.
# !!!!!Data point #10746. Expected: four. Predicted: four.
# !!!!!Data point #10747. Expected: four. Predicted: four.
# !!!!!Data point #10748. Expected: four. Predicted: four.
# !!!!!Data point #10750. Expected: four. Predicted: four.
# !!!!!Data point #10874. Expected: four. Predicted: four.
# !!!!!Data point #10875. Expected: four. Predicted: four.
# !!!!!Data point #10876. Expected: four. Predicted: four.
# !!!!!Data point #10877. Expected: four. Predicted: four.
# !!!!!Data point #10878. Expected: four. Predicted: four.
# !!!!!Data point #10879. Expected: four. Predicted: four.
# !!!!!Data point #10880. Expected: four. Predicted: four.
# !!!!!Data point #10881. Expected: four. Predicted: four.
# #####Data point #10882. Expected: four. Predicted: off.
# !!!!!Data point #10883. Expected: four. Predicted: four.
# !!!!!Data point #10885. Expected: four. Predicted: four.
# #####Data point #10886. Expected: four. Predicted: forward.
# !!!!!Data point #10887. Expected: four. Predicted: four.
# !!!!!Data point #10888. Expected: four. Predicted: four.
# !!!!!Data point #10889. Expected: four. Predicted: four.
# #####Data point #10890. Expected: four. Predicted: on.
# !!!!!Data point #10891. Expected: four. Predicted: four.
# !!!!!Data point #10892. Expected: four. Predicted: four.
# #####Data point #10893. Expected: four. Predicted: off.
# !!!!!Data point #10895. Expected: four. Predicted: four.
# !!!!!Data point #10896. Expected: four. Predicted: four.
# !!!!!Data point #10897. Expected: four. Predicted: four.
# !!!!!Data point #10898. Expected: four. Predicted: four.
# !!!!!Data point #10899. Expected: four. Predicted: four.
# !!!!!Data point #10900. Expected: four. Predicted: four.
# #####Data point #10901. Expected: four. Predicted: forward.
# #####Data point #10902. Expected: four. Predicted: forward.
# #####Data point #10903. Expected: four. Predicted: off.
# !!!!!Data point #10904. Expected: four. Predicted: four.
# #####Data point #10905. Expected: four. Predicted: off.
# !!!!!Data point #10906. Expected: four. Predicted: four.
# !!!!!Data point #10907. Expected: four. Predicted: four.
# !!!!!Data point #10908. Expected: four. Predicted: four.
# !!!!!Data point #10909. Expected: four. Predicted: four.
# !!!!!Data point #10910. Expected: four. Predicted: four.
# !!!!!Data point #10911. Expected: four. Predicted: four.
# !!!!!Data point #10912. Expected: four. Predicted: four.
# !!!!!Data point #10914. Expected: four. Predicted: four.
# !!!!!Data point #10916. Expected: four. Predicted: four.
# !!!!!Data point #10918. Expected: four. Predicted: four.
# !!!!!Data point #10919. Expected: four. Predicted: four.
# !!!!!Data point #10920. Expected: four. Predicted: four.
# !!!!!Data point #10921. Expected: four. Predicted: four.
# !!!!!Data point #10922. Expected: four. Predicted: four.
# !!!!!Data point #10924. Expected: four. Predicted: four.
# !!!!!Data point #10925. Expected: four. Predicted: four.
# #####Data point #10926. Expected: four. Predicted: one.
# !!!!!Data point #10927. Expected: four. Predicted: four.
# !!!!!Data point #10928. Expected: four. Predicted: four.
# #####Data point #10929. Expected: four. Predicted: forward.
# !!!!!Data point #10930. Expected: four. Predicted: four.
# #####Data point #10931. Expected: four. Predicted: off.
# !!!!!Data point #10932. Expected: four. Predicted: four.
# #####Data point #10933. Expected: four. Predicted: forward.
# #####Data point #10934. Expected: four. Predicted: off.
# !!!!!Data point #10935. Expected: four. Predicted: four.
# !!!!!Data point #10936. Expected: four. Predicted: four.
# !!!!!Data point #10937. Expected: four. Predicted: four.
